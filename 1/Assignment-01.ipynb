# %% [markdown]
# ## Lesson-01 Assignment

# %% [markdown]
# >

# %% [markdown]
# `各位同学大家好，欢迎各位开始学习我们的人工智能课程。这门课程假设大家不具备机器学习和人工智能的知识，但是希望大家具备初级的Python编程能力。根据往期同学的实际反馈，我们课程的完结之后 能力能够超过80%的计算机人工智能/深度学习方向的硕士生的能力。`

# %% [markdown]
# ## 本次作业的内容

# %% [markdown]
# #### 1. 复现课堂代码
#
# 在本部分，你需要参照我们给大家的GitHub地址里边的课堂代码，结合课堂内容，复现内容。

# %% [markdown]
# #### 2. 请回答以下问题
#
# 回答以下问题，并将问题发送至 mqgao@kaikeba.com中：
# ```
#     2.1. what do you want to acquire in this course？
#     2.2. what problems do you want to solve？
#     2.3. what’s the advantages you have to finish you goal?
#     2.4. what’s the disadvantages you need to overcome to finish you goal?
#     2.5. How will you plan to study in this course period?
# ```

# %% [markdown]
# #### 3. 如何提交
# 代码 + 此 jupyter 相关，提交至自己的 github 中(**所以请务必把GitHub按照班主任要求录入在Trello中**)；
# 第2问，请提交至mqgao@kaikeba.com邮箱。
# #### 4. 作业截止时间
# 此次作业截止时间为 2019.7.6日

# %% [markdown]
# #### 5. 完成以下问答和编程练习

# %% [markdown]
# >

# %% [markdown]
# ## 基础理论部分

# %% [markdown]
# #### 0. Can you come up out 3 sceneraies which use AI methods?

# %% [markdown]
# Ans: 图像识别、语音识别、情感分析

# %% [markdown]
# #### 1. How do we use Github; Why do we use Jupyter and Pycharm;

# %% [markdown]
# Ans:
# 1.1 Github<br>
# 1）git add <filename>          提出更改，并添加到暂存区<br>
# 2）git commit -m "代码提交信息"   提交改动到了 HEAD<br>
# 3）git push origin master       将这些改动提交到远端仓库<br>
#
# 1.2 Jupyter and Pycharm<br>
# 方便代码管理和交互式编程<br>

# %% [markdown]
# #### 2. What's the Probability Model?

# %% [markdown]
# Ans: A probability model is a mathematical representation of a random phenomenon.

# %% [markdown]
# #### 3. Can you came up with some sceneraies at which we could use Probability Model?

# %% [markdown]
# Ans: 垃圾邮件分类、异常检测

# %% [markdown]
# #### 4. Why do we use probability and what's the difficult points for programming based on parsing and pattern match?

# %% [markdown]
# Ans: <br>基于paring和pattern match的一旦规则发生改变就失效，并且随着场景变得复杂，需要编写大量的规则，难以维护。<br>基于概率的可以通过数据驱动来学习模型，数据发生改变只需重新学习即可,更加灵活且易于维护，同时更能反映事物的内在联系。

# %% [markdown]
# #### 5. What's the Language Model;

# %% [markdown]
# Ans:A statistical language model is a probability distribution over sequences of words.

# %% [markdown]
# #### 6. Can you came up with some sceneraies at which we could use Language Model?

# %% [markdown]
# Ans: 词性标注、语法纠错、新闻分类

# %% [markdown]
# #### 7. What's the 1-gram language model;

# %% [markdown]
#  Ans:
#  $$ Pro(w_1 w_2 w_3 w_4) = Pr(w_1) * P(w_2) * Pr(w_3) * Pr(w_4)$$

# %% [markdown]
# #### 8. What's the disadvantages and advantages of 1-gram language model;

# %% [markdown]
# Ans:<br>
# 优势:简单、计算速度快<br>
# 缺点:丢失词语前后信息

# %% [markdown]
# #### 9. What't the 2-gram models;

# %% [markdown]
# Ans:
# $$ Pro(w_1 w_2 w_3 w_4) = Pr(w_1 | w_2 ) * P(w_2 | w_3 ) * Pr(w_3 | w_4) * Pr(w_4)$$

# %% [markdown]
# ## 编程实践部分

# %% [markdown]
# #### 1. 设计你自己的句子生成器

# %% [markdown]
# 如何生成句子是一个很经典的问题，从1940s开始，图灵提出机器智能的时候，就使用的是人类能不能流畅和计算机进行对话。和计算机对话的一个前提是，计算机能够生成语言。
#
# 计算机如何能生成语言是一个经典但是又很复杂的问题。 我们课程上为大家介绍的是一种基于规则（Rule Based）的生成方法。该方法虽然提出的时间早，但是现在依然在很多地方能够大显身手。值得说明的是，现在很多很实用的算法，都是很久之前提出的，例如，二分查找提出与1940s, Dijstra算法提出于1960s 等等。

# %% [markdown]
# 在著名的电视剧，电影《西部世界》中，这些机器人们语言生成的方法就是使用的SyntaxTree生成语言的方法。
#
# >
# >
#
# ![WstWorld](https://timgsa.baidu.com/timg?image&quality=80&size=b10000_10000&sec=1561818705&di=95ca9ff2ff37fcb88ae47b82c7079feb&src=http://s7.sinaimg.cn/mw690/006BKUGwzy75VK46FMi66&690)
#
# >
# >

# %% [markdown]
# 在这一部分，需要各位同学首先定义自己的语言。 大家可以先想一个应用场景，然后在这个场景下，定义语法。例如：
#
# 在西部世界里，一个”人类“的语言可以定义为：
# ```
# human = """
# human = 自己 寻找 活动
# 自己 = 我 | 俺 | 我们
# 寻找 = 看看 | 找找 | 想找点
# 活动 = 乐子 | 玩的
# """
# ```
#
# 一个“接待员”的语言可以定义为
# ```
# host = """
# host = 寒暄 报数 询问 业务相关 结尾
# 报数 = 我是 数字 号 ,
# 数字 = 单个数字 | 数字 单个数字
# 单个数字 = 1 | 2 | 3 | 4 | 5 | 6 | 7 | 8 | 9
# 寒暄 = 称谓 打招呼 | 打招呼
# 称谓 = 人称 ,
# 人称 = 先生 | 女士 | 小朋友
# 打招呼 = 你好 | 您好
# 询问 = 请问你要 | 您需要
# 业务相关 = 玩玩 具体业务
# 玩玩 = 耍一耍 | 玩一玩
# 具体业务 = 喝酒 | 打牌 | 打猎 | 赌博
# 结尾 = 吗？"""
#
# ```

# %% [markdown]
# 请定义你自己的语法:

# %% [markdown]
# 第一个语法：

# %%
human = """
human = 自己 寻找 活动
自己 = 我 | 俺 | 我们 
寻找 = 看看 | 找找 | 想找点
活动 = 乐子 | 玩的
"""

# %% [markdown]
# 第二个语法：

# %%
host = """
host = 寒暄 报数 询问 业务相关 结尾 
报数 = 我是 数字 号 ,
数字 = 单个数字 | 数字 单个数字 
单个数字 = 1 | 2 | 3 | 4 | 5 | 6 | 7 | 8 | 9 
寒暄 = 称谓 打招呼 | 打招呼
称谓 = 人称 ,
人称 = 先生 | 女士 | 小朋友
打招呼 = 你好 | 您好 
询问 = 请问你要 | 您需要
业务相关 = 玩玩 具体业务
玩玩 = 耍一耍 | 玩一玩
具体业务 = 喝酒 | 打牌 | 打猎 | 赌博
结尾 = 吗？"""

# %% [markdown]
# TODO: 然后，使用自己之前定义的generate函数，使用此函数生成句子。

# %% [markdown]
# TODO: 然后，定义一个函数，generate_n，将generate扩展，使其能够生成n个句子:

# %%
def create_grammar(gram_str, split = '=', line_split = '\n'):
    grammar = {}
    for lines in gram_str.split(line_split):
        if not lines.strip(): continue
        exp,stat = lines.split(split)
        grammar[exp.strip()] = [s.split() for s in stat.split('|')]
    return grammar

# %%
import random
def generate(gram, target):
    if target not in gram: return target
    expand = [generate(gram, t) for t in random.choice(gram[target])]
    return ''.join(expand)

gram = create_grammar(host)
generate(gram, 'host')
# Out:
# '你好我是218号,请问你要玩一玩赌博吗？'

# %%
def generate_n(gram, target, num = 10):
    return [generate(gram, target) for i in range(num)]

generate_n(gram, 'host')
# Out:
# ['你好我是4号,请问你要玩一玩赌博吗？',
#  '女士,你好我是5号,请问你要玩一玩喝酒吗？',
#  '你好我是84号,您需要耍一耍打牌吗？',
#  '你好我是8号,请问你要玩一玩喝酒吗？',
#  '您好我是3号,您需要耍一耍打牌吗？',
#  '小朋友,您好我是3号,请问你要耍一耍打猎吗？',
#  '女士,你好我是86号,您需要耍一耍打牌吗？',
#  '您好我是9号,您需要耍一耍打猎吗？',
#  '您好我是8号,请问你要耍一耍喝酒吗？',
#  '小朋友,您好我是6号,请问你要玩一玩喝酒吗？']

# %% [markdown]
# >

# %% [markdown]
# #### 2. 使用新数据源完成语言模型的训练

# %% [markdown]
# 按照我们上文中定义的`prob_2`函数，我们更换一个文本数据源，获得新的Language Model:
#
# 1. 下载文本数据集（你可以在以下数据集中任选一个，也可以两个都使用）
#     + 可选数据集1，保险行业问询对话集： https://github.com/Computing-Intelligence/insuranceqa-corpus-zh/raw/release/corpus/pool/train.txt.gz
#     + 可选数据集2：豆瓣评论数据集：https://github.com/Computing-Intelligence/datasource/raw/master/movie_comments.csv
# 2. 修改代码，获得新的**2-gram**语言模型
#     + 进行文本清洗，获得所有的纯文本
#     + 将这些文本进行切词
#     + 送入之前定义的语言模型中，判断文本的合理程度

# %% [markdown]
# >

# %%
file_name = './train.txt'
with open(file_name,'r+', encoding='UTF-8') as fp:
    file_str = [line.split('++$++')[2] for line in fp.readlines()]
file_str
# Out:
# [' 法律要求残疾保险吗？ ',
#  ' 债权人可以在死后人寿保险吗？ ',
#  ' 旅行者保险有租赁保险吗？ ',
#  ' 我可以开一辆没有保险的新车吗？ ',
#  ' 人寿保险的现金转出价值是否应纳税？ ',
#  ' 如何报告年金收入？ ',
#  ' AAA家庭保险涵盖什么？ ',
#  ' 什么是简单的退休计划？ ',
#  ' 社会保险残疾保险是什么？ ',
#  ' 汽车保险是否预付？ ',
#  ' 医疗保险B部分盖什么？ ',
#  ' 退伍军人能否获得人寿保险？ ',
#  ' 我的房主保险是否包括失去的结婚戒指？ ',
#  ' 分配风险汽车保险如何工作？ ',
#  ' 我的男朋友可以加我的汽车保险吗？ ',
#  ' 我是否需要提交私人财产车祸索赔的警察报告？ ',
#  ' 全覆盖汽车保险盖修理？ ',
#  ' 人生在伊斯兰教中是否可以接受？ ',
#  ' 健康保险是否覆盖管道逆转？ ',
#  ' 如果您已经诊断为乳腺癌，您可以获得多大的人寿保险？ ',
#  ' 我需要注册医疗保险？ ',
#  ' 短期残疾保险是否工作？ ',
#  ' 房主保险盖池？ ',
#  ' 什么时候要注册医疗保险？ ',
#  ' MIP会影响我的汽车保险吗？ ',
#  ' 蓝十字蓝盾有人寿保险吗？ ',
#  ' 长期护理保险的优点和缺点是什么？ ',
#  ' 医疗保险支付生命预警？ ',
#  ' 我应该买哪种人寿？ ',
#  ' 医疗保险支付HPV筛查吗？ ',
#  ' 哪个是最好的人寿保险？ ',
#  ' 长期护理保险费用多少？ ',
#  ' 固定年金如何安全？ ',
#  ' 要解决人寿保险索赔需要多长时间？ ',
#  ' 是否检查汽车保险信贷？ ',
#  ' 我可以使用HSA支付长期护理保险吗？ ',
#  ' 雇主可以向吸烟者收取更多健康保险费吗？ ',
#  ' 房屋所有权保险通常覆盖什么？ ',
#  ' 没有健康保险的超声波成本是多少？ ',
#  ' 什么是10年期人寿保险？ ',
#  ' 你可以把钱放在一个401K和一个Roth IRA？ ',
#  ' 我可以用丙型肝炎保险吗？ ',
#  ' 什么时候可以注册医疗保险A部分？ ',
#  ' 健康保险何时起源？ ',
#  ' 医疗保险有多重要？ ',
#  ' 租用保险费用多少？ ',
#  ' 我的家庭保险是否覆盖盗窃？ ',
#  ' 租户保险如何受益业主？ ',
#  ' 俄亥俄州雇主是否必须提供健康保险？ ',
#  ' 我应该有多少汽车保险？ ',
#  ' 为什么房主保险增加？ ',
#  ' 谁能买医保？ ',
#  ' 如何清除Medicare B部分？ ',
#  ' 在什么年龄我应该得到长期护理保险？ ',
#  ' 人寿保险死亡福利是否应纳税？ ',
#  ' 什么是医疗储蓄计划？ ',
#  ' 房主保险是否向其他狗盖狗叮咬？ ',
#  ' 医疗保险计划盖什么？ ',
#  ' 全人寿保险是一个好的选择吗？ ',
#  ' 雇主可以提供不同数额的健康保险吗？ ',
#  ' 将来会发生什么医疗保险？ ',
#  ' 一般人寿保险？ ',
#  ' 我的汽车保险是否会如果得到机票呢？ ',
#  ' 租客保险是否包括盗窃？ ',
#  ' 什么是租赁保险？ ',
#  ' 如何计算家庭保险？ ',
#  ' 房主保险是否覆盖下水道维修？ ',
#  ' AARP是否有长期护理保险？ ',
#  ' 短期残疾考虑健康保险吗？ ',
#  ' 在什么年龄你应该得到人寿保险？ ',
#  ' 旅行者家庭保险好吗？ ',
#  ' 谁能得到医疗保险？ ',
#  ' 谁有最优惠的租金保险费率？ ',
#  ' 谁能驾驶你的车在你的保险？ ',
#  ' 医疗保险可以支付养老院吗？ ',
#  ' 如果汽车保险失败，会发生什么？ ',
#  ' 车库门由房主保险覆盖？ ',
#  ' 我在哪里注册医疗保险？ ',
#  ' 如何获得汽车保险最佳交易？ ',
#  ' 在新泽西州如何申请Medicare Part D？ ',
#  ' 哪家公司提供最佳租赁保险？ ',
#  ' 全人寿保险有哪些特点？ ',
#  ' 什么是年金种现金流？ ',
#  ' 可以在乳腺癌后获得人身保险吗？ ',
#  ' 如何找出多少汽车保险呢？ ',
#  ' 如何计划退休与401K？ ',
#  ' 什么是不符合奥巴马的健康保险的税收减免？ ',
#  ' 你能失去医疗福利吗？ ',
#  ' 房主保险是否会损失钻石？ ',
#  ' 长期护理保险费用多少？ ',
#  ' 何时应该停止支付人寿保险？ ',
#  ' 你去医疗保险什么年龄？ ',
#  ' 人寿保险公司如何吸烟？ ',
#  ' 如何确定您是否需要长期护理保险？ ',
#  ' 谁制造汽车保险？ ',
#  ' 什么时候应该得到期限人寿保险？ ',
#  ' 信用与汽车保险有什么关系？ ',
#  ' 家庭保险是否支付屋顶更换？ ',
#  ' 谁拥有最好和最便宜的汽车保险？ ',
#  ' 你能租汽车保险吗？ ',
#  ' 房主保险涵盖什么？ ',
#  ' 我可以为我母亲购买长期护理保险吗？ ',
#  ' 什么是完全实行人寿保险？ ',
#  ' 我可以得到高血压的人寿保险吗？ ',
#  ' 如何找到好的租客保险？ ',
#  ' 什么是考虑用于保险目的的跑车？ ',
#  ' 家庭保险涵盖什么？ ',
#  ' 为什么现在重新计划退休？ ',
#  ' 为什么要为汽车保险付钱？ ',
#  ' 移动家庭保险如何便宜？ ',
#  ' 可以在乳腺癌后获得人身保险吗？ ',
#  ' 多少人使用残疾保险？ ',
#  ' 您的汽车保险涵盖谁？ ',
#  ' 什么是Medigap计划？ ',
#  ' 如何增加健康保险？ ',
#  ' 长期残疾保险多久？ ',
#  ' 全人寿保险不好吗 ',
#  ' 犹他州的平均车险是多少？ ',
#  ' 伟大的西方人寿是否涵盖旅游保险？ ',
#  ' 定期人寿保险在特定年龄结束吗？ ',
#  ' 房主保险是否覆盖火器？ ',
#  ' 共同基金的资产净值是多少？ ',
#  ' 哪些国家有最好的健康保险？ ',
#  ' 为什么重要计划退休？ ',
#  ' 多少残疾保险足够了？ ',
#  ' 骑手在人寿保险中意味着什么？ ',
#  ' 你为长期护理保险支付多少钱？ ',
#  ' 我可以要求什么租客保险？ ',
#  ' 健康保险额定值是多少？ ',
#  ' 你如何计算人寿保险的期望回报？ ',
#  ' 没有驾照吗？ ',
#  ' 什么时候是符合医疗保险D部分的人？ ',
#  ' 汽车保险是联邦要求吗？ ',
#  ' 你能得到不良信用的汽车保险吗？ ',
#  ' HIPPA适用于人寿保险公司吗？ ',
#  ' DUI后汽车保险费用多少？ ',
#  ' 购买家庭时多少保险？ ',
#  ' 什么是Medigap政策？ ',
#  ' 租客保险是否涵盖失去的订婚戒指？ ',
#  ' Obamacare覆盖Medigap？ ',
#  ' 全国租赁保险多少？ ',
#  ' 谁卖出抵押人寿保险？ ',
#  ' 我的人寿保险是否覆盖跳伞？ ',
#  ' 健康保险是否覆盖皮肤清除手术？ ',
#  ' 没有健康保险的皮肤科医生花费多少钱？ ',
#  ' 在哪里得到健康保险与预先存在的条件？ ',
#  ' 是否USAA卖人寿保险？ ',
#  ' 联邦政府是否有残疾保险？ ',
#  ' 什么是人寿保险股？ ',
#  ' 残疾人保险在平均水平上有多大？ ',
#  ' 你可以提交人寿保险吗？ ',
#  ' 人寿保险是否考虑收入？ ',
#  ' 什么时候应该得到残疾保险？ ',
#  ' 租金保险费用多少？ ',
#  ' 新罕布什尔州是否需要汽车保险？ ',
#  ' 您的工资有多少由残疾保险承担？ ',
#  ' 哪个药店接受医疗保险？ ',
#  ' 需要多长时间才能获得汽车保险？ ',
#  ' 什么是医疗保险？ ',
#  ' 如何确定期限人寿保险的现金价值？ ',
#  ' 人寿保险为您的葬礼付钱吗？ ',
#  ' 你的健康保险可以让孩子多久？ ',
#  ' 健康保险税何时可以扣除？ ',
#  ' Suze Orman对可变年金说什么？ ',
#  ' 可以用Fsa支付健康保险费吗？ ',
#  ' 沃尔玛是否接受医疗保险？ ',
#  ' 汽车保险可以转移吗？ ',
#  ' 什么是SR22保险？ ',
#  ' 没有工作可以得到汽车保险吗？ ',
#  ' 你经常支付健康保险吗？ ',
#  ' 受益人何时收到人寿保险？ ',
#  ' 如果我没有汽车保险我可以租车吗？ ',
#  ' 医疗保险支付救护车吗？ ',
#  ' 何时需要家庭保修保险？ ',
#  ' 家庭保险是否覆盖您的烟囱？ ',
#  ' 我需要多少人寿保险？ ',
#  ' 财产保险与房主保险相同吗？ ',
#  ' 当你年轻时，人寿保险是否更便宜？ ',
#  ' Aflac是否提供短期残疾保险？ ',
#  ' 长期残疾是否涵盖医疗保险？ ',
#  ' 失去使用意味着什么是房主保险？ ',
#  ' 汽车保险是否在您的信用报告上？ ',
#  ' 如何驾驶没有保险的新车？ ',
#  ' 为什么汽车保险在俄亥俄州那么昂贵？ ',
#  ' 我需要南卡罗来纳州的残疾保险吗？ ',
#  ' 一个公寓大楼可否要求您将其作为您的租客保险的共同保单持有人？ ',
#  ' 什么是医疗保险要花费我？ ',
#  ' 被医疗保险部分D覆盖的Hyoscyamine是吗？ ',
#  ' 长期护理保险的平均成本是多少？ ',
#  ' 医疗保险支付IVF多少钱？ ',
#  ' 医疗保险和医疗补助金有什么区别？ ',
#  ' 人寿保险支付多少？ ',
#  ' 为什么需要残疾保险？ ',
#  ' 健康保险何时成为强制性 ',
#  ' 结婚影响汽车保险？ ',
#  ' 医疗保险费用会在2014年上涨吗？ ',
#  ' 汽车保险多久？ ',
#  ' AAA家庭保险好吗？ ',
#  ' 我可以保险金从汽车事故吗？ ',
#  ' 你可以去没有汽车保险的监狱吗？ ',
#  ' 您可以作为房地产经纪人获得健康保险吗？ ',
#  ' 什么时候开放注册Medigap政策？ ',
#  ' 何时使用医疗保险？ ',
#  ' 有限责任公司有退休计划吗？ ',
#  ' 福特野马的汽车保险费用多少？ ',
#  ' 保险会覆盖我的车上的一棵树吗？ ',
#  ' 人寿保险政策的面值是多少？ ',
#  ' 什么是安联人寿保险？ ',
#  ' 人寿保险的现金投降价值是多少？ ',
#  ' 租客保险是否盖车库盗窃？ ',
#  ' 高胆固醇是否会影响人寿保险费率？ ',
#  ' 医疗保险支付疼痛泵？ ',
#  ' 什么是人寿保险类型？ ',
#  ' 国家农场寿险对THC进行测试？ ',
#  ' 哪里可以为个人购买健康保险？ ',
#  ' 什么时候可以从医疗保险优势计划中消失？ ',
#  ' 人寿保险去财产？ ',
#  ' 租客保险是否涵盖啮齿动物损伤？ ',
#  ' 当我可以从我的401K提款？ ',
#  ' 公寓可以让你有租赁保险吗？ ',
#  ' Medigap是否覆盖眼睛检查？ ',
#  ' 哪里最好的地方得到房主的保险？ ',
#  ' 人寿保险期满是什么意思？ ',
#  ' 租客保险是否覆盖踏板车？ ',
#  ' 房主的保险是否会包裹食物？ ',
#  ' 家庭保险是否覆盖火灾？ ',
#  ' 当你退出工作时，健康保险停止吗？ ',
#  ' 你可以购买停车许可证的汽车保险吗？ ',
#  ' 为什么人寿保险成本更高？ ',
#  ' 人寿养老计划是什么？ ',
#  ' 老年人的人寿保险费用多少？ ',
#  ' 何时使用您的家庭保险？ ',
#  ' 房主保险是否涵盖基金会问题？ ',
#  ' 当我取消人寿保险时会发生什么？ ',
#  ' 如果我取消人寿保险政策会发生什么？ ',
#  ' 残疾人保险如何必要？ ',
#  ' 什么是Aetna人寿保险？ ',
#  ' 如何支付健康保险？ ',
#  ' 租金保险不包括什么？ ',
#  ' 人寿保险何时进入？ ',
#  ' 什么是没有汽车保险的罚款？ ',
#  ' 租客保险是否覆盖我的车库？ ',
#  ' 寿险是否影响FAFSA？ ',
#  ' 非法移民可以获得汽车保险吗？ ',
#  ' 房主保险是否覆盖水泵？ ',
#  ' 购买健康保险时要注意什么？ ',
#  ' 房主保险覆盖地下水？ ',
#  ' 你可以通过电话获得汽车保险吗？ ',
#  ' 医疗保险是否考虑福利？ ',
#  ' 是否必须在65岁申请医疗保险？ ',
#  ' 什么类型的退休计划是基于公式？ ',
#  ' 如果我提到人寿保险申请，会发生什么？ ',
#  ' 人寿保险公司可以检查病历吗？ ',
#  ' DUI会影响人寿保险多久？ ',
#  ' 长期护理保险是什么意思？ ',
#  ' 退休计划在工作中涵盖什么？ ',
#  ' 汽车保险在纽约有多少？ ',
#  ' 你为什么要退休？ ',
#  ' 短期残疾保险是否涵盖孕产妇？ ',
#  ' 健康保险在离职时结束什么时候？ ',
#  ' 人寿保险在支付时纳税吗？ ',
#  ' 谁是最便宜的汽车保险为新的司机？ ',
#  ' Medigap支付什么？ ',
#  ' 为什么男士汽车保险更高？ ',
#  ' 我可以从没有保险的企业租车吗？ ',
#  ' 汽车保险公司能放你吗？ ',
#  ' 什么是长期健康保险？ ',
#  ' 房主保险增加吗？ ',
#  ' 什么是退休计划信托？ ',
#  ' 如何从人寿保险中提取现金价值？ ',
#  ' 什么是退休幸存者和残疾保险？ ',
#  ' 年金排除率是多少？ ',
#  ' 残疾保险是什么意思？ ',
#  ' 年金可以转入401K吗？ ',
#  ' 你可以要求减少医疗保险吗 ',
#  ' 我的房主保险是否覆盖了一个漏水屋顶？ ',
#  ' 医疗保险何时覆盖血液测试？ ',
#  ' 人寿保险公司可以访问医疗记录吗？ ',
#  ' 20年的人寿保险是多少？ ',
#  ' 什么是人寿保险？ ',
#  ' 什么是家庭保险的年度保费？ ',
#  ' 我应该买什么样的人寿保险？ ',
#  ' Xarelto是由Medicare覆盖吗？ ',
#  ' 我的健康保险什么时候停了？ ',
#  ' 美元人寿保险如何运作？ ',
#  ' 是否可以取消人寿保险？ ',
#  ' 谁应该受益于人寿保险？ ',
#  ' 你可以从群体健康保险中掉下来吗？ ',
#  ' 人寿保险是否覆盖癌症？ ',
#  ' 什么是补充长期残疾保险？ ',
#  ' 可以结婚的孩子留在父母汽车保险吗？ ',
#  ' 你可以要求医疗保险和私人健康吗？ ',
#  ' 什么是人寿保险年金？ ',
#  ' 我可以期待赔偿残疾保险？ ',
#  ' 什么是相互全人寿保险？ ',
#  ' 什么是养老金计划赞助？ ',
#  ' 什么国家有国家残疾保险？ ',
#  ' 长期残疾保险涵盖什么？ ',
#  ' 你可以切换家庭保险吗？ ',
#  ' 谁从谁购买长期护理保险？ ',
#  ' 医疗保险覆盖Zostavax？ ',
#  ' Aflac癌症保险值得吗？ ',
#  ' 你可以切换汽车保险中期政策吗？ ',
#  ' 我的索赔被我的犯罪记录否认是对的吗？ ',
#  ' 人寿保险在你的W2？ ',
#  ' 养老院可以拿人寿保险吗？ ',
#  ' 人寿保险是否缴纳税款？ ',
#  ' 意外人寿值得吗？ ',
#  ' 健康保险是否覆盖了Tummy Tuck？ ',
#  ' 健康保险通常是否覆盖整形术？ ',
#  ' 人寿保险是死后的一部分吗？ ',
#  ' 何时获得长期护理保险？ ',
#  ' 我如何知道我有什么健康保险？ ',
#  ' 人寿保险代理人的平均工资是多少？ ',
#  ' 谁发明了重大疾病保险？ ',
#  ' 伟大的剪辑是否提供健康保险？ ',
#  ' Krystexxa被Medicare覆盖吗？ ',
#  ' 什么是合适的房主保险？ ',
#  ' 汽车保险在加州有多少17岁的女性？ ',
#  ' 医疗保险盖Xanax？ ',
#  ' 人寿保险通常费用多少？ ',
#  ' 我年轻时应该买人寿吗？ ',
#  ' 如何选择Medigap保险？ ',
#  ' 什么样的健康保险是最好的？ ',
#  ' 健康保险是否覆盖STD测试？ ',
#  ' 什么是即期年金？ ',
#  ' 健康保险费是什么意思？ ',
#  ' 对癌症患者而言，没有保险怎么办？ ',
#  ' 什么时候要求健康保险开始？ ',
#  ' 租赁保险是什么？ ',
#  ' 为什么年金是不好的投资？ ',
#  ' 医疗保险是否限制了在任何给定时间内可以拥有的超声心动图数量？ ',
#  ' 如何确定人寿保险金额？ ',
#  ' 健康保险是否涵盖青光眼？ ',
#  ' 什么是残疾保险？ ',
#  ' 汽车保险每年应该增加吗？ ',
#  ' 哪个是更好的医疗保险或医疗保险的优势？ ',
#  ' 什么会导致人寿保险？ ',
#  ' 自由共有人寿保险？ ',
#  ' 可变人寿保险是否具有现金价值？ ',
#  ' 医疗保险的年费是多少？ ',
#  ' 我可以在我的父母身上购买人寿保险吗？ ',
#  ' 家庭保险可以覆盖水暖吗？ ',
#  ' 如何为有限责任公司获得健康保险？ ',
#  ' 如何建立人寿保险信托？ ',
#  ' 工作时你可以获得医疗保险吗？ ',
#  ' 我在哪里买人寿保险？ ',
#  ' 什么让汽车保险更便宜？ ',
#  ' 要求人寿保险政策多长时间？ ',
#  ' 我是一个非司机，需要一辆卡车用于我的工作，我想要保证我的帮手为我带来任何问题？ ',
#  ' 什么是最好的医疗保健计划？ ',
#  ' 什么是集体残疾保险？ ',
#  ' 你能赔偿保险上的车钥匙吗？ ',
#  ' 哪家汽车保险公司是最好的？ ',
#  ' 谁写空置家庭保险？ ',
#  ' 什么类型的水损害由房主保险？ ',
#  ' 获得汽车保险需要什么信息？ ',
#  ' 我需要建筑商风险保险购买我们将在搬家前进行主要装修的家园吗？ ',
#  ' 医疗保险上睑下垂？ ',
#  ' 医疗保险的优势成本多少？ ',
#  ' 你可以从医疗保险优势转变为Medigap吗？ ',
#  ' 我的房主保险是否会覆盖模具损坏？ ',
#  ' 我需要什么保险退休？ ',
#  ' 什么是自助餐计划健康保险？ ',
#  ' 法律要求什么汽车保险？ ',
#  ' 我的医疗保险是否覆盖我的妻子？ ',
#  ' 家庭保险的覆盖面是什么？ ',
#  ' 什么是幸存者普遍人寿保险？ ',
#  ' 医疗保险支付给沃克？ ',
#  ' 如何将汽车保险作为高风险驾驶者？ ',
#  ' 哪些年金对我来说是对的？ ',
#  ' 孕妇可以得到人寿保险吗？ ',
#  ' 医疗保险盖牙科？ ',
#  ' 如果我有糖尿病，我可以得到人寿保险吗？ ',
#  ' 什么公司有最好的长期护理保险？ ',
#  ' 什么是基本生活和广告D保险？ ',
#  ' 医疗保险覆盖复合药物吗 ',
#  ' 年金参与率是多少？ ',
#  ' 什么是5年期人寿保险？ ',
#  ' 你如何设立年金？ ',
#  ' 永久性人寿保险是一个好主意吗？ ',
#  ' 残疾保险支付多久？ ',
#  ' 什么是菲律宾保诚人寿保险？ ',
#  ' 60岁的人寿保险多少？ ',
#  ' 你有两个医疗保健补品吗？ ',
#  ' 什么是租赁保险的好处？ ',
#  ' 人寿保险是否涵盖酒精中毒？ ',
#  ' 好的人寿保险政策是多少？ ',
#  ' QDRO是否适用人寿保险？ ',
#  ' 80岁可以获得长期护理保险吗？ ',
#  ' 你能退出退休计划吗？ ',
#  ' 租客保险是否覆盖止赎？ ',
#  ' 什么是私人残疾保险？ ',
#  ' 房主保险是否覆盖游泳池受损？ ',
#  ' 为什么我需要Medigap政策？ ',
#  ' 房主保险是否覆盖炉？ ',
#  ' 医疗保险支付LPC吗？ ',
#  ' 如何取消Scotia人寿保险？ ',
#  ' 如何知道有人有人寿保险？ ',
#  ' 健康保险如何影响妇女的退休行为？ ',
#  ' 医疗保险覆盖的是脊医吗？ ',
#  ' 什么公司有最便宜的长期护理保险在科罗拉多州？ ',
#  ' 公寓需要多少租金保险？ ',
#  ' 需要多少家庭保险？ ',
#  ' 谁是最好的汽车保险提供商？ ',
#  ' 哪里投诉家庭保险？ ',
#  ' Medigap还是Medicare优势更好？ ',
#  ' 何时投降人寿保险？ ',
#  ' 什么是人寿保险的优点和缺点？ ',
#  ' 健康保险费用多少一个人？ ',
#  ' 租金保险是否覆盖了笔记本电脑？ ',
#  ' 在伊利诺伊州受益人的人寿保险是否应纳税？ ',
#  ' 我可以否认健康保险吗？ ',
#  ' 为什么孩子需要人寿保险？ ',
#  ' 残疾保险是否具有现金价值？ ',
#  ' 你应该多少人寿保险？ ',
#  ' 租客保险是否覆盖被盗的自行车？ ',
#  ' 租赁保险的好处是什么？ ',
#  ' 在哪里可以获得全人寿保险？ ',
#  ' 我的孩子是我的汽车保险吗？ ',
#  ' 什么是医疗保健部分B用于？ ',
#  ' 租金保险涵盖什么？ ',
#  ' 退休计划如何借款？ ',
#  ' 你能保持汽车保险索赔的钱吗？ ',
#  ' 家庭保险是否覆盖中央空气？ ',
#  ' 如果没有合格事件，我可以取消我的健康保险吗？ ',
#  ' 我应该在这个经济中购买长期护理保险吗？ ',
#  ' 什么是人寿保险年限？ ',
#  ' 我需要为我们的图书馆购买残疾保险吗？ ',
#  ' 单身高级人寿保险费用多少？ ',
#  ' Suze Orman认为可变年金是什么？ ',
#  ' 租客保险是否值得成本？ ',
#  ' 如何设定个人退休计划？ ',
#  ' 年金可以抵押吗？ ',
#  ' 何时购买人身保险？ ',
#  ' 租赁保险是否涵盖公寓的洪水？ ',
#  ' 人寿保险政策涵盖？ ',
#  ' 为什么BCBSTX提供一个骑手，并为偏头痛率？ ',
#  ' 哪里可以获得廉价的房主保险？ ',
#  ' 如果你超重，如何获得健康保险？ ',
#  ' 你能得到汽车保险延期吗？ ',
#  ' 我如何知道我需要多少人寿保险？ ',
#  ' 谁能购买人寿保险？ ',
#  ' 多少可能的残疾保险费用？ ',
#  ' 医疗保健处方药是否合法？ ',
#  ' 购买汽车保险时要注意什么？ ',
#  ' 房主保险是否涵盖ATV事故？ ',
#  ' 什么是最佳家庭保险政策？ ',
#  ' 在哪里可以找到廉价汽车保险在阿肯色州？ ',
#  ' 地球人寿保险多少？ ',
#  ' 谁是最大的人寿保险公司？ ',
#  ' 医疗保险支付超声心动图吗 ',
#  ' 我可以在我的父母身上购买人寿吗？ ',
#  ' 谁支付社会保障残疾保险？ ',
#  ' 我应该在哪里得到期限人寿保险？ ',
#  ' 为什么我的房东想要我有租金保险？ ',
#  ' 什么因素影响家庭保险的成本？ ',
#  ' 谁应该购买全期人寿保险？ ',
#  ' 健康保险是谁合约？ ',
#  ' 为什么人们购买残疾保险？ ',
#  ' 如果您有两项健康保险政策，该如何运作？ ',
#  ' 你可以随时取消租金保险吗？ ',
#  ' 医疗保险支付肺炎疫苗吗？ ',
#  ' 如何在线注册Medicare？ ',
#  ' 债权人可以索赔人寿保险吗？ ',
#  ' 什么时候太晚计划退休？ ',
#  ' 如何将医疗保险作为二级保险？ ',
#  ' 谁能驾驶我的汽车保险？ ',
#  ' 短期健康保险是否工作？ ',
#  ' 我的健康保险公司可以改变我的政策吗？ ',
#  ' 代理人对人寿保险有多少？ ',
#  ' 我的前妻可以为我保险吗 ',
#  ' 我的房主保险是多少？ ',
#  ' 房主保险是否涵盖法定费用？ ',
#  ' 可以终止人寿保险吗？ ',
#  ' 什么时候可以兑现人寿保险？ ',
#  ' 健康保险专员做什么？ ',
#  ' 我可否按附表C扣除人寿保险费？ ',
#  ' 为什么房主保险重要？ ',
#  ' 人寿保险成长时会发生什么？ ',
#  ' 如何找出有多少人寿保险？ ',
#  ' 为什么选择长期护理保险？ ',
#  ' 2014年我可以否认健康保险吗？ ',
#  ' 美国银行出售人寿保险？ ',
#  ' PPO为健康保险提供什么？ ',
#  ' 租金保险通常覆盖什么？ ',
#  ' 家庭保险是否会覆盖气体泄漏？ ',
#  ' Obamacare会提高我的医疗保险费吗？ ',
#  ' 我们有多少人寿保险代理人？ ',
#  ' 需要多长时间才能获得家庭保险捆绑？ ',
#  ' 谁有最便宜的人寿保险费率？ ',
#  ' 什么是更好的期限或全人寿保险？ ',
#  ' 医疗保险考试包括什么？ ',
#  ' 医疗保险支付超声波？ ',
#  ' 401K计算为退休计划吗？ ',
#  ' 家庭保险是否覆盖单位？ ',
#  ' 我可以在哪里兼职和获得健康保险？ ',
#  ' 一辆跑车有多少保险？ ',
#  ' 难以获得残疾保险？ ',
#  ' 我可以从没有保险的私人派对开车吗？ ',
#  ' 你能多快得到汽车保险？ ',
#  ' 十七岁的摩托车保险有多少？ ',
#  ' 如果每个人都死亡，人寿如何工作？ ',
#  ' 租赁者保险多长时间？ ',
#  ' 我的汽车保险可以叫我吗 ',
#  ' 健康保险是否涵盖宫内节育器？ ',
#  ' 医疗保险覆盖家庭护理援助？ ',
#  ' 我可以要求房主对我的税收保险吗？ ',
#  ' 房主保险需要什么？ ',
#  ' 在伊斯兰教中禁止人寿保险吗？ ',
#  ' 什么是全人寿保险的目的？ ',
#  ' 如何在阿拉巴马州获得人寿保险牌照？ ',
#  ' 租客保险是否涵盖动物？ ',
#  ' 没有赡养费的单身人士需要人寿保险吗？ ',
#  ' 什么是最佳人寿保险公司？ ',
#  ' 什么是房主保险粘合剂？ ',
#  ' 对健康保险可以扣除的是什么意思？ ',
#  ' 联邦政府是否提供残疾保险？ ',
#  ' 医疗保险支付腹部成形术吗？ ',
#  ' 汽车保险覆盖面对我来说是什么？ ',
#  ' 什么是人寿保险？ ',
#  ' 你可以在普遍的人寿保险中现金吗？ ',
#  ' 全人寿保险的平均成本是多少？ ',
#  ' 家庭保险报价需要什么信息？ ',
#  ' 什么是集团普遍人寿保险？ ',
#  ' 我应该有多少人寿保险？ ',
#  ' 购买人寿时需要什么？ ',
#  ' 国家农场租赁保险是否覆盖盗窃？ ',
#  ' 租客保险是否盖车库物品？ ',
#  ' 我需要地震保险吗？ ',
#  ' 谁符合人寿保险资格？ ',
#  ' 租客保险在火灾中遇到什么？ ',
#  ' 什么是保障欠租人保险？ ',
#  ' 汽车保险费用多少？ ',
#  ' 人寿保险可以竞争吗？ ',
#  ' 护理家庭护理是由医疗保险覆盖吗？ ',
#  ' 什么是人寿保险报价？ ',
#  ' 什么时候有人符合医疗保险D部分？ ',
#  ' 我可以在另一个国家使用我的健康保险吗？ ',
#  ' 为什么要翻转我的401K？ ',
#  ' 您需要在缅因州出售人寿的许可证吗？ ',
#  ' 医生有多少伤残保险？ ',
#  ' 医疗保险可以三分之一吗？ ',
#  ' 什么是HSA健康保险计划？ ',
#  ' 健康保险的年龄限制是多少？ ',
#  ' 如何找到注册投资顾问？ ',
#  ' 谁能兑现人寿保险？ ',
#  ' 一个人有两个人寿保险政策吗？ ',
#  ' 2014年什么是医疗保险？ ',
#  ' 何时开始长期护理保险？ ',
#  ' 怀俄明州如何获得医疗保险资格？ ',
#  ' 谁应该得到残疾保险？ ',
#  ' 最便宜的租客保险在哪里？ ',
#  ' 人寿保险可以信托吗？ ',
#  ' 什么是没有健康保险在Obamacare下的罚款？ ',
#  ' 如何获得房主保险报价？ ',
#  ' 人寿保险是否缴纳税款？ ',
#  ' 汽车保险在加利福尼亚有多少是全覆盖的？ ',
#  ' 你可以在线申请Medicare B部分吗？ ',
#  ' 我应该有多少年金？ ',
#  ' 汽车保险可以在您的信用报告吗？ ',
#  ' 我正在越过国家。我在交通过程中保险我的财产是什么？ ',
#  ' PCN站在健康保险卡上什么？ ',
#  ' 多少长期护理保险足够？ ',
#  ' 买房租的保险怎么办？ ',
#  ' 健康保险通过工作多少钱？ ',
#  ' 新泽西州个人健康保险多少？ ',
#  ' 房主保险覆盖失去的结婚戒指？ ',
#  ' 人寿保险需要血液检查吗？ ',
#  ' 汽车保险是否覆盖司机或汽车？ ',
#  ' 如何购买医疗保险？ ',
#  ' 孩子可以多长时间养父母健康保险？ ',
#  ' 安全视野医疗保险补充？ ',
#  ' 租金保险费用一个月多少？ ',
#  ' 哪个医疗保险B部分计划是最好的？ ',
#  ' 有多少雇主提供残疾保险？ ',
#  ' 什么类型的工作提供最佳健康保险？ ',
#  ' 什么是良好的租赁保险政策？ ',
#  ' 你应该有多长时间的人寿保险？ ',
#  ' 医疗保险补贴F是什么？ ',
#  ' 人寿保险是否进入房地产？ ',
#  ' 什么是军人集团人寿保险？ ',
#  ' 为什么要购买补充残疾保险？ ',
#  ' 没有身体健康吗？ ',
#  ' 我的租客保险是否覆盖我的手机？ ',
#  ' 家庭危害保险是什么？ ',
#  ' 你能否在医疗保险方面声称成形术？ ',
#  ' 全人寿保险是否真的有意义？ ',
#  ' 为什么人寿保险这么便宜？ ',
#  ' 弗吉尼亚州需要租赁保险吗？ ',
#  ' 医疗保险覆盖眼镜多少钱？ ',
#  ' 你如何确定你需要多长时间的人寿保险？ ',
#  ' 你可以取消人寿保险吗？ ',
#  ' 如果我没有健康保险，我会被征税吗？ ',
#  ' 什么是服务承包商的医疗费用？ ',
#  ' 租客保险是否盖枪盗窃？ ',
#  ' 什么是儿童最佳人寿保险？ ',
#  ' Allstate做人寿保险？ ',
#  ' 宾夕法尼亚州的汽车保险最低费用是多少？ ',
#  ' 我可以有私人保险和医疗保险吗？ ',
#  ' 为什么要买残疾保险？ ',
#  ' 谁能添加到我的汽车保险？ ',
#  ' 你可以取消全人寿保险吗？ ',
#  ' 汽车保险在加价车票之后增加多少？ ',
#  ' 汽车保险何时下跌？ ',
#  ' 残疾保险是否推荐？ ',
#  ' 为什么全民保险这么昂贵？ ',
#  ' 谁应该拥有你的人寿保险？ ',
#  ' 什么是替代医疗保险？ ',
#  ' 我父母的人寿保险是多少？ ',
#  ' 谁出售定期人寿保险？ ',
#  ' 谁能购买人寿保险？ ',
#  ' 我的代理人告诉我我已经涵盖了产前保健，但是现在我怀孕了，发现我没有涵盖任何产妇相关的东西。我该怎么办？ ',
#  ' 谁卖最便宜的汽车保险？ ',
#  ' 我需要什么牌子卖残疾保险？ ',
#  ' 如果失业，我可以得到健康保险吗？ ',
#  ' 我可以把我的老人家长给我的健康保险吗？ ',
#  ' 什么是全人寿保险？ ',
#  ' 你可以在人寿保险中现金吗？ ',
#  ' 什么是人寿保险证书？ ',
#  ' 什么是租赁保险的使用？ ',
#  ' 汽车保险是否覆盖鹿？ ',
#  ' 医疗保险是否可以用尽？ ',
#  ' 什么是两种类型的残疾保险？ ',
#  ' 什么是不合格退休计划？ ',
#  ' 什么是即时年金的排除比例？ ',
#  ' 多少是健康保险的保险费？ ',
#  ' 眼镜蛇健康保险好吗？ ',
#  ' 需要信用检查才能获得人寿保险？ ',
#  ' 为什么人们得到残疾保险？ ',
#  ' 健康保险公司可以告诉你吸烟吗？ ',
#  ' 如果你在医疗保险中，你可以在YMCA获得Silvers Sneakers会员资格吗？ ',
#  ' 任何人都可以拿出人寿保险吗？ ',
#  ' 什么时候需要商业汽车保险？ ',
#  ' 为什么长期护理保险市场这么小？ ',
#  ' 何时开始全员保险？ ',
#  ' 如何将我的保险转让给另一辆车？ ',
#  ' ROP在人寿保险中意味着什么？ ',
#  ' 什么是长期残疾保险？ ',
#  ' 你有不止一个人寿保险吗？ ',
#  ' 如何购买新房子的房主保险？ ',
#  ' 如何获得我自己的健康保险？ ',
#  ' 长期护理保险费可以扣除吗？ ',
#  ' 债务人可以承担人寿保险吗？ ',
#  ' 在哪里获得租赁保险？ ',
#  ' 医疗保险批准金额多少是眼镜？ ',
#  ' 人寿保险血液检查寻找什么？ ',
#  ' 什么时候可以获得医疗福利？ ',
#  ' 年金可以用于抵押品吗？ ',
#  ' 什么是医疗保健中的MOOP？ ',
#  ' 如何购买短期残疾保险？ ',
#  ' 屋主保险盖屋顶塌方？ ',
#  ' 为什么Roth IRA免税？ ',
#  ' 谁需要严重疾病保险？ ',
#  ' 人寿保险公司如何知道你死了？ ',
#  ' 哪里获得最佳健康保险？ ',
#  ' 人寿保险如何便宜？ ',
#  ' 汽车保险可以扣除多少？ ',
#  ' 家庭保险在火灾中遇到什么？ ',
#  ' 失业是否影响家庭保险？ ',
#  ' 为什么要获得Medigap？ ',
#  ' 住房保险费用是什么？ ',
#  ' 花费多少钱来偿付全人寿保险？ ',
#  ' 什么是顶帽退休计划？ ',
#  ' 78岁可以获得人寿保险吗？ ',
#  ' 家庭保险公司可以放弃你吗？ ',
#  ' 健康保险是否覆盖牙种植体？ ',
#  ' 如果我不能获得房主保险，会发生什么？ ',
#  ' 宝力人寿保险是什么？ ',
#  ' 人寿保险检查要多久清除？ ',
#  ' 新墨西哥应该在哪里购买健康保险？ ',
#  ' 什么是租赁保险？ ',
#  ' Suze Orman对长期护理保险有什么看法？ ',
#  ' 得克萨斯州一个人的健康保险多少？ ',
#  ' 我可以用我的汽车保险租车吗？ ',
#  ' 如何申请医疗保险B部分？ ',
#  ' 我可以为我的孩子买车吗？ ',
#  ' 医疗保险何时覆盖家庭保健？ ',
#  ' 房主保险是否覆盖暖通空调？ ',
#  ' 什么是401C的早期罚款？ ',
#  ' 健康保险是否适用？ ',
#  ' 平均租金保险费用多少？ ',
#  ' 债务追回者可以追求人寿保险吗？ ',
#  ' 个人健康保险费用多少？ ',
#  ' 健康保险是否补贴？ ',
#  ' 全人寿保险贷款如何运作？ ',
#  ' 什么是汽车身体伤害保险？ ',
#  ' 我需要多少保险？ ',
#  ' 如何在线购买残疾保险？ ',
#  ' 整形术是健康保险涵盖的吗？ ',
#  ' 房东要求租客保险是否合法？ ',
#  ' 医疗保险盖STD测试？ ',
#  ' 我怎么知道我的车祸是否完成？ ',
#  ' 房屋医疗保险涵盖什么？ ',
#  ' 健康保险是否影响老年工人的就业？ ',
#  ' 人寿保险通过遗嘱？ ',
#  ' 谁能为不可撤销的人寿保险信托做出贡献？ ',
#  ' 家庭日托需要什么样的保险？ ',
#  ' 药物过量被人寿保险覆盖吗？ ',
#  ' 谁是符合残疾保险条件？ ',
#  ' 谁需要全人寿保险？ ',
#  ' D部分医疗保险是否免费？ ',
#  ' 你有两个医疗保险和VA的好处？ ',
#  ' 搬家时需要改车保险吗？ ',
#  ' 如何选择合适的退休计划？ ',
#  ' 家庭保险是否包含被盗现金？ ',
#  ' 人寿保险的面值是多少？ ',
#  ' 谁有最佳的Medigap计划？ ',
#  ' 未成年人能否成为人寿保险受益人？ ',
#  ' 密歇根州需要汽车保险吗？ ',
#  ' 如何注册眼镜蛇健康保险？ ',
#  ' 401（K）计划能否提供足够的退休资源？ ',
#  ' 军人退休金是否合格退休计划？ ',
#  ' 卖年金怎么办？ ',
#  ' 每个人65岁以上是否符合医疗保险？ ',
#  ' 如果您超过80岁，您可以获得长期护理保险吗？ ',
#  ' 纽约人寿保险代理人有多少？ ',
#  ' 独资经营者可以扣除残疾保险费吗？ ',
#  ' 雇主可以向老年雇主收取更高的费用吗？ ',
#  ' 房主的保险是否覆盖了地下室？ ',
#  ' 如何通知医疗保险？ ',
#  ' 医疗保险优势与医疗保险保险的区别是什么？ ',
#  ' 健康保险为新生儿费用多少？ ',
#  ' 汽车保险结算是否应纳税？ ',
#  ' 租金保险是否包括被盗现金？ ',
#  ' 为什么我们需要健康保险公司？ ',
#  ' 我应该在俄亥俄州多少辆汽车保险？ ',
#  ' 短期残疾保险多久？ ',
#  ' 我退休时会有医疗保险吗？ ',
#  ' 我的兄弟可以驾驶我的汽车没有保险吗？ ',
#  ' 65岁之前可以享受医疗保险吗？ ',
#  ' 为什么健康保险存在？ ',
#  ' 医疗保险A和医疗保险B之间有什么区别？ ',
#  ' 什么时候最好的时候买年金？ ',
#  ' 人寿保险血液和尿液测试是什么？ ',
#  ' 离婚期间人寿保险怎么办？ ',
#  ' 哪里购买好人寿保险？ ',
#  ' 基本租金保险费用多少？ ',
#  ' 西北共同人寿保险投资良好？ ',
#  ' 可以从终身人寿保险中获得现金吗？ ',
#  ' 哪里可以获得低廉的租金保险？ ',
#  ' 60岁的健康保险多少钱？ ',
#  ' 您的投资组合应该在年金中多少？ ',
#  ' 哪里可以得到没有车的保险？ ',
#  ' 是否需要租赁保险？ ',
#  ' 如何在房主保险上节省资金？ ',
#  ' 什么是生命和TPD保险？ ',
#  ' 你可以在其他人身上购买人寿吗？ ',
#  ' 要成为保险代理人的学院专业学习是什么？ ',
#  ' 医疗保险覆盖DME用品？ ',
#  ' 你能否在宾夕法尼亚州借贷退休计划？ ',
#  ' 长期护理保险费用是多少？ ',
#  ' 康涅狄格州需要多少房主保险？ ',
#  ' 医疗保险是否有房屋恢复？ ',
#  ' 什么公司有最便宜的租客保险在宾夕法尼亚州？ ',
#  ' 为什么有人被剥夺人寿保险？ ',
#  ' FAFSA计算年金吗？ ',
#  ' 如何购买我自己的健康保险？ ',
#  ' 我可以扣除汽车保险费吗？ ',
#  ' 401K中的关键员工是谁？ ',
#  ' 你可以从罗斯401K撤出吗？ ',
#  ' 为什么进口汽车保险更昂贵？ ',
#  ' 如果你生病，你能得到人寿保险吗？ ',
#  ' 如果我吸烟，人寿保险是否知道？ ',
#  ' 谁的人寿保险是不可靠的？ ',
#  ' 现在是一个好时机去买年金吗？ ',
#  ' 家庭住宅的住房金额是多少？ ',
#  ' 我应该得到什么租赁保险？ ',
#  ' 人寿是抵押的法定要求吗？ ',
#  ' 字母T在医疗保险号码中是什么意思？ ',
#  ' 人寿保险销售是个好职业吗？ ',
#  ' 你住哪里影响你的汽车保险费率？ ',
#  ' 丈夫和妻子都有Roth IRA？ ',
#  ' 健康保险在加拿大免费吗？ ',
#  ' 我的配偶是否必须在我的汽车保险上？ ',
#  ' 谁应该设立一个Roth IRA？ ',
#  ' Geico是否提供定期人寿保险？ ',
#  ' 什么是人寿保险创造一个即时财产？ ',
#  ' 什么是自雇健康保险？ ',
#  ' 没有健康保险多少罚款？ ',
#  ' 什么是家庭保险？ ',
#  ' 人寿保险费用是多少？ ',
#  ' 我可以随时注册医疗保险D部分吗？ ',
#  ' 谁应该是我人寿保险的受益人？ ',
#  ' 什么是医疗保险区域C？ ',
#  ' 租客保险是否包括盗窃自行车？ ',
#  ' 什么是选择定期人寿保险？ ',
#  ' 人人有健康保险吗？ ',
#  ' 我可以在我的男朋友健康保险吗？ ',
#  ' 全面覆盖健康保险？ ',
#  ' 如何获得Obamacare？ ',
#  ' 您需要在伊利诺斯出售人寿的许可证吗？ ',
#  ' 为什么长期残疾保险重要？ ',
#  ' 地下池增加房主保险吗？ ',
#  ' 我们如何找出什么保险公司保险我的邻居的房子？ ',
#  ' 你可以1035从人寿到年金？ ',
#  ' 我应该在密歇根州购买长期护理保险？ ',
#  ' 2014年医疗保险费将上涨吗？ ',
#  ' 我可以在另一个州有汽车保险吗？ ',
#  ' 人寿应该多少钱？ ',
#  ' 医疗保险D部封盖Cymbalta？ ',
#  ' 如何获得短期残疾保险？ ',
#  ' 人寿保险代理人在伊利诺伊州做了多少工作？ ',
#  ' 医疗保险覆盖丙型肝炎筛查？ ',
#  ' 谁调整可变年金？ ',
#  ' 谁提供购买寿命年金？ ',
#  ' 为什么我需要严重的疾病保险？ ',
#  ' AARP有汽车保险吗？ ',
#  ' 汽车保险报价是否会影响您的信用评分？ ',
#  ' 医疗保险覆盖在老人家庭护理中吗？ ',
#  ' 人寿保险的两大基本类型是什么？ ',
#  ' 哪一类人寿保险派息？ ',
#  ' 农场局提供租赁保险吗？ ',
#  ' 为什么我的汽车保险上涨？ ',
#  ' 雇主可以取消健康保险吗？ ',
#  ' 你不会因没有健康保险而被罚款多少？ ',
#  ' 哪个是最好的经典汽车保险？ ',
#  ' Medigap的好处是什么？ ',
#  ' 网上汽车保险报价准确度如何？ ',
#  ' 丈夫有多少人寿保险？ ',
#  ' 残疾保险是否涵盖酒精中毒？ ',
#  ' 谁能在田纳西州卖年金？ ',
#  ' 什么资格作为健康保险的资格赛？ ',
#  ' Esurance是否提供人寿保险？ ',
#  ' 健康保险对家庭3成本有多大？ ',
#  ' 何时购买长期残疾保险？ ',
#  ' 哪些私人健康保险涵盖整容手术？ ',
#  ' 房主保险盖屋顶损坏？ ',
#  ' 哪里买个人残疾保险？ ',
#  ' 如果我参加工作中的退休计划，我可以参加IRA吗？ ',
#  ' 国税局能否挽救人寿保险？ ',
#  ' 你可以从人寿保险贷款吗？ ',
#  ' 为什么我的房东想要我租赁保险？ ',
#  ' 医疗保险支付任何牙科工作？ ',
#  ' 什么是保险替代成本在房主保险？ ',
#  ' 汽车保险怎么开始？ ',
#  ' 如何选择最佳汽车保险？ ',
#  ' 谁出售长期护理保险？ ',
#  ' 医疗保险是否覆盖艾滋病毒药物？ ',
#  ' 什么被认为健康保险失效？ ',
#  ' 我需要什么信息获得汽车保险？ ',
#  ' 什么是最佳Medigap或Medicare优势？ ',
#  ' 购买我自己的健康保险是否便宜？ ',
#  ' 医疗保险覆盖的折射？ ',
#  ' 全球人寿保险有多好？ ',
#  ' 我可以用现有条件购买健康保险吗？ ',
#  ' 租金在马萨诸塞州的保险费用多少？ ',
#  ' 健康保险是否覆盖流感疫苗？ ',
#  ' 我能救我的人寿保险公司吗？ ',
#  ' 房主保险在浴室里是否覆盖水损害？ ',
#  ' 固定年金有多好？ ',
#  ' 人寿保险是否可以由债权人承担？ ',
#  ' 如何注册Medicare A？ ',
#  ' 罗德岛的医疗保险资格是多少？ ',
#  ' 退休计划多少钱？ ',
#  ' 什么是年金错误？ ',
#  ' 租赁保险在爱荷华州覆盖什么？ ',
#  ' 我可以驾驶我父母的汽车保险吗？ ',
#  ' 你如何购买年金？ ',
#  ' 我可以获得长期护理保险的资格吗？ ',
#  ' 房主保险是否覆盖爆管？ ',
#  ' 401K如果退出工作怎么办？ ',
#  ' 如果我有狼疮，我可以得到人寿保险吗？ ',
#  ' 年金可以丢钱吗？ ',
#  ' 人寿如何保险资产？ ',
#  ' 房主保险是否会从屋顶泄漏中覆盖水面？ ',
#  ' 什么时候可以从医疗保险优势切换到Medigap？ ',
#  ' 什么是实行人寿保险的罚则？ ',
#  ' 高免赔额健康保险费用多少？ ',
#  ' 我可以扣除长期护理保险费吗？ ',
#  ' 我应该做长期残疾保险吗？ ',
#  ' 什么影响到房主的保险费率？ ',
#  ' 家庭保险是否覆盖了泄漏屋顶？ ',
#  ' 我需要多少年的长期护理保险？ ',
#  ' 房主保险托管如何工作？ ',
#  ' 人寿保险是如何在死亡时征收的？ ',
#  ' 私人残疾保险如何影响社会保障残疾？ ',
#  ' 谁提供残疾保险？ ',
#  ' 医疗保险B部分盖实验室工作吗？ ',
#  ' 什么是最佳长期护理保险公司？ ',
#  ' 利润分享退休计划？ ',
#  ' 医疗费用一年多少钱？ ',
#  ' 租客保险是否覆盖手机损坏？ ',
#  ' 华盛顿医疗保险的资格是多少？ ',
#  ' 19岁以上汽车保险费用多少？ ',
#  ' 长期护理保险可以固定吗？ ',
#  ' 什么是健康保险的免赔额？ ',
#  ' 什么是汽车保险堆？ ',
#  ' 租客保险是否覆盖子列表？ ',
#  ' 旅行保险是否值钱？ ',
#  ' 受家庭保险覆盖的湿腐蚀？ ',
#  ' 汽车保险在MA中多少钱？ ',
#  ' 汽车保险可以在您父母的姓名吗？ ',
#  ' 租金保险是否涵盖洪灾？ ',
#  ' 长期护理保险费可以增加吗？ ',
#  ' 房屋保险何时开始？ ',
#  ' 何时可以购买Medigap政策？ ',
#  ' 健康保险什么时候覆盖一个馅饼馅饼？ ',
#  ' Aflac癌症保险支付什么？ ',
#  ' 如何检查供应商的医疗保险资格？ ',
#  ' UMPD是否对被盗车辆造成损害？ ',
#  ' Genworth长期护理保险涵盖什么？ ',
#  ' 残疾保险的定义是什么？ ',
#  ' 房主保险是否覆盖电涌？ ',
#  ' 严重疾病保险是否覆盖关节炎？ ',
#  ' 企业家如何获得健康保险？ ',
#  ' 哪种残疾保险是最好的？ ',
#  ' 医疗保健有效地用于帮助美国人吗？ ',
#  ' 什么是儿童骑手人寿保险？ ',
#  ' 什么是第一人寿保险公司？ ',
#  ' 退休计划做什么？ ',
#  ' Grange汽车保险是否租用汽车？ ',
#  ' 你可以在线购买人寿保险吗？ ',
#  ' 家庭保险怎么办？ ',
#  ' 医疗保险支付输血费用吗？ ',
#  ' 谁免于购买健康保险？ ',
#  ' 医疗保险是多少B部分？ ',
#  ' 关键疾病保险的好处是什么？ ',
#  ' 我可以开一家汽车保险公司吗？ ',
#  ' 人寿保险是否必要？ ',
#  ' 为什么人寿是单方面合同？ ',
#  ' 什么是医疗保险终身储备天？ ',
#  ' 租客保险是否涵盖车辆损坏？ ',
#  ' 什么是最佳的Medigap保险？ ',
#  ' 什么是健康保险的裁决？ ',
#  ' 人寿保险被认为是医疗补助的资产？ ',
#  ' 你需要多少残疾保险？ ',
#  ' 一辆新车全面覆盖汽车保险多少？ ',
#  ' 特拉华州最好的人寿保险是什么？ ',
#  ' 汽车保险公司可以放弃你吗？ ',
#  ' 什么是Medigap？ ',
#  ' 自由相关租车保险？ ',
#  ' 要花多长时间才能收到人寿保险？ ',
#  ' VA提供残疾保险吗？ ',
#  ' 基本租金保险多少？ ',
#  ' Aetna学生健康保险是什么？ ',
#  ' 寿险如何快速发放？ ',
#  ' 谁必须购买健康保险？ ',
#  ' 残疾保险是一个好主意吗？ ',
#  ' 家庭保险会增加一个池吗？ ',
#  ' 什么是不可撤销的人寿保险信托的主要目的？ ',
#  ' 没有健康保险的尿分析费用多少？ ',
#  ' 我可以在不属于我的汽车上获得保险吗？ ',
#  ' 富国银行是否提供人寿保险？ ',
#  ' 退休储蓄计划可以有多少选择？ ',
#  ' 为什么我需要Medigap？ ',
#  ' 人寿保险是否真的有效？ ',
#  ' 整个生命在保险中意味着什么？ ',
#  ' 年金公司如何赚钱？ ',
#  ' 什么是最便宜的汽车保险？ ',
#  ' 汽车保险联邦法律 ',
#  ' 人寿保险需要多长时间？ ',
#  ' 房主保险是否覆盖了使用？ ',
#  ' 医疗保健HIC代表什么？ ',
#  ' 为什么全人寿保险好投资？ ',
#  ' 房主保险覆盖电力浪潮？ ',
#  ' 什么是集体健康保险？ ',
#  ' 年金利率上涨吗 ',
#  ' 什么时候可以注册健康保险？ ',
#  ' 租人保险是否需要？ ',
#  ' 什么是递延年金？ ',
#  ' 如何计算合格的年金？ ',
#  ' 人寿可以得到什么？ ',
#  ' 我可以保险，不修车吗？ ',
#  ' 如果我的车被盗，保险将支付什么？ ',
#  ' 为什么我们需要严重的疾病保险？ ',
#  ' 何时开启强制性汽车保险？ ',
#  ' 国营农场有定期人寿保险吗？ ',
#  ' 典型的房主保险多少？ ',
#  ' 美国健康保险在海外工作吗？ ',
#  ' 什么是最好的房主保险？ ',
#  ' 什么是少年全人寿保险？ ',
#  ' 在房主保险中要寻找什么？ ',
#  ' 不能拥有汽车可以获得Sr22保险吗？ ',
#  ' 人寿保险社区财产？ ',
#  ' 谁拥有西南生活？ ',
#  ' 汽车保险金多少钱？ ',
#  ' 我需要知道什么才能获得房主保险？ ',
#  ' 汽车保险是否覆盖了一个破裂的挡风玻璃？ ',
#  ' 谁在北达科他州管理人寿保险？ ',
#  ' 你能否继续保持父母的健康保险？ ',
#  ' 公司是否要提供退休计划？ ',
#  ' 租客保险是否对房产造成损害？ ',
#  ' 退休时我需要人寿保险吗？ ',
#  ' 群变人寿保险如何运作？ ',
#  ' 为什么选择Medigap或Medicare的优势？ ',
#  ' 两个人的健康保险多少钱？ ',
#  ' 如何在线销售人寿保险？ ',
#  ' 我可以在线报价人寿保险吗？ ',
#  ' 一个人死后长时间得到人寿保险？ ',
#  ' 你可以从整个人寿保险中借钱吗？ ',
#  ' 人寿保险与健康保险的区别是什么？ ',
#  ' 如何注册医疗保险B部分在线？ ',
#  ' AD＆D与人寿保险有何不同？ ',
#  ' 健康保险是否覆盖ED药物？ ',
#  ' 谁获得医疗保险总结通知？ ',
#  ' 什么时候是Medicare主要付款人？ ',
#  ' 医疗支付医生多少钱？ ',
#  ' 什么时候什么时候适合医疗保险？ ',
#  ' 普遍人寿保险是否过期？ ',
#  ...]

# %%
import re
def token(string):
    return re.findall('\w+', string)

# %%
clean_str_list = [token(s)[0] for s in file_str]
clean_str_list
# Out:
# ['法律要求残疾保险吗',
#  '债权人可以在死后人寿保险吗',
#  '旅行者保险有租赁保险吗',
#  '我可以开一辆没有保险的新车吗',
#  '人寿保险的现金转出价值是否应纳税',
#  '如何报告年金收入',
#  'AAA家庭保险涵盖什么',
#  '什么是简单的退休计划',
#  '社会保险残疾保险是什么',
#  '汽车保险是否预付',
#  '医疗保险B部分盖什么',
#  '退伍军人能否获得人寿保险',
#  '我的房主保险是否包括失去的结婚戒指',
#  '分配风险汽车保险如何工作',
#  '我的男朋友可以加我的汽车保险吗',
#  '我是否需要提交私人财产车祸索赔的警察报告',
#  '全覆盖汽车保险盖修理',
#  '人生在伊斯兰教中是否可以接受',
#  '健康保险是否覆盖管道逆转',
#  '如果您已经诊断为乳腺癌',
#  '我需要注册医疗保险',
#  '短期残疾保险是否工作',
#  '房主保险盖池',
#  '什么时候要注册医疗保险',
#  'MIP会影响我的汽车保险吗',
#  '蓝十字蓝盾有人寿保险吗',
#  '长期护理保险的优点和缺点是什么',
#  '医疗保险支付生命预警',
#  '我应该买哪种人寿',
#  '医疗保险支付HPV筛查吗',
#  '哪个是最好的人寿保险',
#  '长期护理保险费用多少',
#  '固定年金如何安全',
#  '要解决人寿保险索赔需要多长时间',
#  '是否检查汽车保险信贷',
#  '我可以使用HSA支付长期护理保险吗',
#  '雇主可以向吸烟者收取更多健康保险费吗',
#  '房屋所有权保险通常覆盖什么',
#  '没有健康保险的超声波成本是多少',
#  '什么是10年期人寿保险',
#  '你可以把钱放在一个401K和一个Roth',
#  '我可以用丙型肝炎保险吗',
#  '什么时候可以注册医疗保险A部分',
#  '健康保险何时起源',
#  '医疗保险有多重要',
#  '租用保险费用多少',
#  '我的家庭保险是否覆盖盗窃',
#  '租户保险如何受益业主',
#  '俄亥俄州雇主是否必须提供健康保险',
#  '我应该有多少汽车保险',
#  '为什么房主保险增加',
#  '谁能买医保',
#  '如何清除Medicare',
#  '在什么年龄我应该得到长期护理保险',
#  '人寿保险死亡福利是否应纳税',
#  '什么是医疗储蓄计划',
#  '房主保险是否向其他狗盖狗叮咬',
#  '医疗保险计划盖什么',
#  '全人寿保险是一个好的选择吗',
#  '雇主可以提供不同数额的健康保险吗',
#  '将来会发生什么医疗保险',
#  '一般人寿保险',
#  '我的汽车保险是否会如果得到机票呢',
#  '租客保险是否包括盗窃',
#  '什么是租赁保险',
#  '如何计算家庭保险',
#  '房主保险是否覆盖下水道维修',
#  'AARP是否有长期护理保险',
#  '短期残疾考虑健康保险吗',
#  '在什么年龄你应该得到人寿保险',
#  '旅行者家庭保险好吗',
#  '谁能得到医疗保险',
#  '谁有最优惠的租金保险费率',
#  '谁能驾驶你的车在你的保险',
#  '医疗保险可以支付养老院吗',
#  '如果汽车保险失败',
#  '车库门由房主保险覆盖',
#  '我在哪里注册医疗保险',
#  '如何获得汽车保险最佳交易',
#  '在新泽西州如何申请Medicare',
#  '哪家公司提供最佳租赁保险',
#  '全人寿保险有哪些特点',
#  '什么是年金种现金流',
#  '可以在乳腺癌后获得人身保险吗',
#  '如何找出多少汽车保险呢',
#  '如何计划退休与401K',
#  '什么是不符合奥巴马的健康保险的税收减免',
#  '你能失去医疗福利吗',
#  '房主保险是否会损失钻石',
#  '长期护理保险费用多少',
#  '何时应该停止支付人寿保险',
#  '你去医疗保险什么年龄',
#  '人寿保险公司如何吸烟',
#  '如何确定您是否需要长期护理保险',
#  '谁制造汽车保险',
#  '什么时候应该得到期限人寿保险',
#  '信用与汽车保险有什么关系',
#  '家庭保险是否支付屋顶更换',
#  '谁拥有最好和最便宜的汽车保险',
#  '你能租汽车保险吗',
#  '房主保险涵盖什么',
#  '我可以为我母亲购买长期护理保险吗',
#  '什么是完全实行人寿保险',
#  '我可以得到高血压的人寿保险吗',
#  '如何找到好的租客保险',
#  '什么是考虑用于保险目的的跑车',
#  '家庭保险涵盖什么',
#  '为什么现在重新计划退休',
#  '为什么要为汽车保险付钱',
#  '移动家庭保险如何便宜',
#  '可以在乳腺癌后获得人身保险吗',
#  '多少人使用残疾保险',
#  '您的汽车保险涵盖谁',
#  '什么是Medigap计划',
#  '如何增加健康保险',
#  '长期残疾保险多久',
#  '全人寿保险不好吗',
#  '犹他州的平均车险是多少',
#  '伟大的西方人寿是否涵盖旅游保险',
#  '定期人寿保险在特定年龄结束吗',
#  '房主保险是否覆盖火器',
#  '共同基金的资产净值是多少',
#  '哪些国家有最好的健康保险',
#  '为什么重要计划退休',
#  '多少残疾保险足够了',
#  '骑手在人寿保险中意味着什么',
#  '你为长期护理保险支付多少钱',
#  '我可以要求什么租客保险',
#  '健康保险额定值是多少',
#  '你如何计算人寿保险的期望回报',
#  '没有驾照吗',
#  '什么时候是符合医疗保险D部分的人',
#  '汽车保险是联邦要求吗',
#  '你能得到不良信用的汽车保险吗',
#  'HIPPA适用于人寿保险公司吗',
#  'DUI后汽车保险费用多少',
#  '购买家庭时多少保险',
#  '什么是Medigap政策',
#  '租客保险是否涵盖失去的订婚戒指',
#  'Obamacare覆盖Medigap',
#  '全国租赁保险多少',
#  '谁卖出抵押人寿保险',
#  '我的人寿保险是否覆盖跳伞',
#  '健康保险是否覆盖皮肤清除手术',
#  '没有健康保险的皮肤科医生花费多少钱',
#  '在哪里得到健康保险与预先存在的条件',
#  '是否USAA卖人寿保险',
#  '联邦政府是否有残疾保险',
#  '什么是人寿保险股',
#  '残疾人保险在平均水平上有多大',
#  '你可以提交人寿保险吗',
#  '人寿保险是否考虑收入',
#  '什么时候应该得到残疾保险',
#  '租金保险费用多少',
#  '新罕布什尔州是否需要汽车保险',
#  '您的工资有多少由残疾保险承担',
#  '哪个药店接受医疗保险',
#  '需要多长时间才能获得汽车保险',
#  '什么是医疗保险',
#  '如何确定期限人寿保险的现金价值',
#  '人寿保险为您的葬礼付钱吗',
#  '你的健康保险可以让孩子多久',
#  '健康保险税何时可以扣除',
#  'Suze',
#  '可以用Fsa支付健康保险费吗',
#  '沃尔玛是否接受医疗保险',
#  '汽车保险可以转移吗',
#  '什么是SR22保险',
#  '没有工作可以得到汽车保险吗',
#  '你经常支付健康保险吗',
#  '受益人何时收到人寿保险',
#  '如果我没有汽车保险我可以租车吗',
#  '医疗保险支付救护车吗',
#  '何时需要家庭保修保险',
#  '家庭保险是否覆盖您的烟囱',
#  '我需要多少人寿保险',
#  '财产保险与房主保险相同吗',
#  '当你年轻时',
#  'Aflac是否提供短期残疾保险',
#  '长期残疾是否涵盖医疗保险',
#  '失去使用意味着什么是房主保险',
#  '汽车保险是否在您的信用报告上',
#  '如何驾驶没有保险的新车',
#  '为什么汽车保险在俄亥俄州那么昂贵',
#  '我需要南卡罗来纳州的残疾保险吗',
#  '一个公寓大楼可否要求您将其作为您的租客保险的共同保单持有人',
#  '什么是医疗保险要花费我',
#  '被医疗保险部分D覆盖的Hyoscyamine是吗',
#  '长期护理保险的平均成本是多少',
#  '医疗保险支付IVF多少钱',
#  '医疗保险和医疗补助金有什么区别',
#  '人寿保险支付多少',
#  '为什么需要残疾保险',
#  '健康保险何时成为强制性',
#  '结婚影响汽车保险',
#  '医疗保险费用会在2014年上涨吗',
#  '汽车保险多久',
#  'AAA家庭保险好吗',
#  '我可以保险金从汽车事故吗',
#  '你可以去没有汽车保险的监狱吗',
#  '您可以作为房地产经纪人获得健康保险吗',
#  '什么时候开放注册Medigap政策',
#  '何时使用医疗保险',
#  '有限责任公司有退休计划吗',
#  '福特野马的汽车保险费用多少',
#  '保险会覆盖我的车上的一棵树吗',
#  '人寿保险政策的面值是多少',
#  '什么是安联人寿保险',
#  '人寿保险的现金投降价值是多少',
#  '租客保险是否盖车库盗窃',
#  '高胆固醇是否会影响人寿保险费率',
#  '医疗保险支付疼痛泵',
#  '什么是人寿保险类型',
#  '国家农场寿险对THC进行测试',
#  '哪里可以为个人购买健康保险',
#  '什么时候可以从医疗保险优势计划中消失',
#  '人寿保险去财产',
#  '租客保险是否涵盖啮齿动物损伤',
#  '当我可以从我的401K提款',
#  '公寓可以让你有租赁保险吗',
#  'Medigap是否覆盖眼睛检查',
#  '哪里最好的地方得到房主的保险',
#  '人寿保险期满是什么意思',
#  '租客保险是否覆盖踏板车',
#  '房主的保险是否会包裹食物',
#  '家庭保险是否覆盖火灾',
#  '当你退出工作时',
#  '你可以购买停车许可证的汽车保险吗',
#  '为什么人寿保险成本更高',
#  '人寿养老计划是什么',
#  '老年人的人寿保险费用多少',
#  '何时使用您的家庭保险',
#  '房主保险是否涵盖基金会问题',
#  '当我取消人寿保险时会发生什么',
#  '如果我取消人寿保险政策会发生什么',
#  '残疾人保险如何必要',
#  '什么是Aetna人寿保险',
#  '如何支付健康保险',
#  '租金保险不包括什么',
#  '人寿保险何时进入',
#  '什么是没有汽车保险的罚款',
#  '租客保险是否覆盖我的车库',
#  '寿险是否影响FAFSA',
#  '非法移民可以获得汽车保险吗',
#  '房主保险是否覆盖水泵',
#  '购买健康保险时要注意什么',
#  '房主保险覆盖地下水',
#  '你可以通过电话获得汽车保险吗',
#  '医疗保险是否考虑福利',
#  '是否必须在65岁申请医疗保险',
#  '什么类型的退休计划是基于公式',
#  '如果我提到人寿保险申请',
#  '人寿保险公司可以检查病历吗',
#  'DUI会影响人寿保险多久',
#  '长期护理保险是什么意思',
#  '退休计划在工作中涵盖什么',
#  '汽车保险在纽约有多少',
#  '你为什么要退休',
#  '短期残疾保险是否涵盖孕产妇',
#  '健康保险在离职时结束什么时候',
#  '人寿保险在支付时纳税吗',
#  '谁是最便宜的汽车保险为新的司机',
#  'Medigap支付什么',
#  '为什么男士汽车保险更高',
#  '我可以从没有保险的企业租车吗',
#  '汽车保险公司能放你吗',
#  '什么是长期健康保险',
#  '房主保险增加吗',
#  '什么是退休计划信托',
#  '如何从人寿保险中提取现金价值',
#  '什么是退休幸存者和残疾保险',
#  '年金排除率是多少',
#  '残疾保险是什么意思',
#  '年金可以转入401K吗',
#  '你可以要求减少医疗保险吗',
#  '我的房主保险是否覆盖了一个漏水屋顶',
#  '医疗保险何时覆盖血液测试',
#  '人寿保险公司可以访问医疗记录吗',
#  '20年的人寿保险是多少',
#  '什么是人寿保险',
#  '什么是家庭保险的年度保费',
#  '我应该买什么样的人寿保险',
#  'Xarelto是由Medicare覆盖吗',
#  '我的健康保险什么时候停了',
#  '美元人寿保险如何运作',
#  '是否可以取消人寿保险',
#  '谁应该受益于人寿保险',
#  '你可以从群体健康保险中掉下来吗',
#  '人寿保险是否覆盖癌症',
#  '什么是补充长期残疾保险',
#  '可以结婚的孩子留在父母汽车保险吗',
#  '你可以要求医疗保险和私人健康吗',
#  '什么是人寿保险年金',
#  '我可以期待赔偿残疾保险',
#  '什么是相互全人寿保险',
#  '什么是养老金计划赞助',
#  '什么国家有国家残疾保险',
#  '长期残疾保险涵盖什么',
#  '你可以切换家庭保险吗',
#  '谁从谁购买长期护理保险',
#  '医疗保险覆盖Zostavax',
#  'Aflac癌症保险值得吗',
#  '你可以切换汽车保险中期政策吗',
#  '我的索赔被我的犯罪记录否认是对的吗',
#  '人寿保险在你的W2',
#  '养老院可以拿人寿保险吗',
#  '人寿保险是否缴纳税款',
#  '意外人寿值得吗',
#  '健康保险是否覆盖了Tummy',
#  '健康保险通常是否覆盖整形术',
#  '人寿保险是死后的一部分吗',
#  '何时获得长期护理保险',
#  '我如何知道我有什么健康保险',
#  '人寿保险代理人的平均工资是多少',
#  '谁发明了重大疾病保险',
#  '伟大的剪辑是否提供健康保险',
#  'Krystexxa被Medicare覆盖吗',
#  '什么是合适的房主保险',
#  '汽车保险在加州有多少17岁的女性',
#  '医疗保险盖Xanax',
#  '人寿保险通常费用多少',
#  '我年轻时应该买人寿吗',
#  '如何选择Medigap保险',
#  '什么样的健康保险是最好的',
#  '健康保险是否覆盖STD测试',
#  '什么是即期年金',
#  '健康保险费是什么意思',
#  '对癌症患者而言',
#  '什么时候要求健康保险开始',
#  '租赁保险是什么',
#  '为什么年金是不好的投资',
#  '医疗保险是否限制了在任何给定时间内可以拥有的超声心动图数量',
#  '如何确定人寿保险金额',
#  '健康保险是否涵盖青光眼',
#  '什么是残疾保险',
#  '汽车保险每年应该增加吗',
#  '哪个是更好的医疗保险或医疗保险的优势',
#  '什么会导致人寿保险',
#  '自由共有人寿保险',
#  '可变人寿保险是否具有现金价值',
#  '医疗保险的年费是多少',
#  '我可以在我的父母身上购买人寿保险吗',
#  '家庭保险可以覆盖水暖吗',
#  '如何为有限责任公司获得健康保险',
#  '如何建立人寿保险信托',
#  '工作时你可以获得医疗保险吗',
#  '我在哪里买人寿保险',
#  '什么让汽车保险更便宜',
#  '要求人寿保险政策多长时间',
#  '我是一个非司机',
#  '什么是最好的医疗保健计划',
#  '什么是集体残疾保险',
#  '你能赔偿保险上的车钥匙吗',
#  '哪家汽车保险公司是最好的',
#  '谁写空置家庭保险',
#  '什么类型的水损害由房主保险',
#  '获得汽车保险需要什么信息',
#  '我需要建筑商风险保险购买我们将在搬家前进行主要装修的家园吗',
#  '医疗保险上睑下垂',
#  '医疗保险的优势成本多少',
#  '你可以从医疗保险优势转变为Medigap吗',
#  '我的房主保险是否会覆盖模具损坏',
#  '我需要什么保险退休',
#  '什么是自助餐计划健康保险',
#  '法律要求什么汽车保险',
#  '我的医疗保险是否覆盖我的妻子',
#  '家庭保险的覆盖面是什么',
#  '什么是幸存者普遍人寿保险',
#  '医疗保险支付给沃克',
#  '如何将汽车保险作为高风险驾驶者',
#  '哪些年金对我来说是对的',
#  '孕妇可以得到人寿保险吗',
#  '医疗保险盖牙科',
#  '如果我有糖尿病',
#  '什么公司有最好的长期护理保险',
#  '什么是基本生活和广告D保险',
#  '医疗保险覆盖复合药物吗',
#  '年金参与率是多少',
#  '什么是5年期人寿保险',
#  '你如何设立年金',
#  '永久性人寿保险是一个好主意吗',
#  '残疾保险支付多久',
#  '什么是菲律宾保诚人寿保险',
#  '60岁的人寿保险多少',
#  '你有两个医疗保健补品吗',
#  '什么是租赁保险的好处',
#  '人寿保险是否涵盖酒精中毒',
#  '好的人寿保险政策是多少',
#  'QDRO是否适用人寿保险',
#  '80岁可以获得长期护理保险吗',
#  '你能退出退休计划吗',
#  '租客保险是否覆盖止赎',
#  '什么是私人残疾保险',
#  '房主保险是否覆盖游泳池受损',
#  '为什么我需要Medigap政策',
#  '房主保险是否覆盖炉',
#  '医疗保险支付LPC吗',
#  '如何取消Scotia人寿保险',
#  '如何知道有人有人寿保险',
#  '健康保险如何影响妇女的退休行为',
#  '医疗保险覆盖的是脊医吗',
#  '什么公司有最便宜的长期护理保险在科罗拉多州',
#  '公寓需要多少租金保险',
#  '需要多少家庭保险',
#  '谁是最好的汽车保险提供商',
#  '哪里投诉家庭保险',
#  'Medigap还是Medicare优势更好',
#  '何时投降人寿保险',
#  '什么是人寿保险的优点和缺点',
#  '健康保险费用多少一个人',
#  '租金保险是否覆盖了笔记本电脑',
#  '在伊利诺伊州受益人的人寿保险是否应纳税',
#  '我可以否认健康保险吗',
#  '为什么孩子需要人寿保险',
#  '残疾保险是否具有现金价值',
#  '你应该多少人寿保险',
#  '租客保险是否覆盖被盗的自行车',
#  '租赁保险的好处是什么',
#  '在哪里可以获得全人寿保险',
#  '我的孩子是我的汽车保险吗',
#  '什么是医疗保健部分B用于',
#  '租金保险涵盖什么',
#  '退休计划如何借款',
#  '你能保持汽车保险索赔的钱吗',
#  '家庭保险是否覆盖中央空气',
#  '如果没有合格事件',
#  '我应该在这个经济中购买长期护理保险吗',
#  '什么是人寿保险年限',
#  '我需要为我们的图书馆购买残疾保险吗',
#  '单身高级人寿保险费用多少',
#  'Suze',
#  '租客保险是否值得成本',
#  '如何设定个人退休计划',
#  '年金可以抵押吗',
#  '何时购买人身保险',
#  '租赁保险是否涵盖公寓的洪水',
#  '人寿保险政策涵盖',
#  '为什么BCBSTX提供一个骑手',
#  '哪里可以获得廉价的房主保险',
#  '如果你超重',
#  '你能得到汽车保险延期吗',
#  '我如何知道我需要多少人寿保险',
#  '谁能购买人寿保险',
#  '多少可能的残疾保险费用',
#  '医疗保健处方药是否合法',
#  '购买汽车保险时要注意什么',
#  '房主保险是否涵盖ATV事故',
#  '什么是最佳家庭保险政策',
#  '在哪里可以找到廉价汽车保险在阿肯色州',
#  '地球人寿保险多少',
#  '谁是最大的人寿保险公司',
#  '医疗保险支付超声心动图吗',
#  '我可以在我的父母身上购买人寿吗',
#  '谁支付社会保障残疾保险',
#  '我应该在哪里得到期限人寿保险',
#  '为什么我的房东想要我有租金保险',
#  '什么因素影响家庭保险的成本',
#  '谁应该购买全期人寿保险',
#  '健康保险是谁合约',
#  '为什么人们购买残疾保险',
#  '如果您有两项健康保险政策',
#  '你可以随时取消租金保险吗',
#  '医疗保险支付肺炎疫苗吗',
#  '如何在线注册Medicare',
#  '债权人可以索赔人寿保险吗',
#  '什么时候太晚计划退休',
#  '如何将医疗保险作为二级保险',
#  '谁能驾驶我的汽车保险',
#  '短期健康保险是否工作',
#  '我的健康保险公司可以改变我的政策吗',
#  '代理人对人寿保险有多少',
#  '我的前妻可以为我保险吗',
#  '我的房主保险是多少',
#  '房主保险是否涵盖法定费用',
#  '可以终止人寿保险吗',
#  '什么时候可以兑现人寿保险',
#  '健康保险专员做什么',
#  '我可否按附表C扣除人寿保险费',
#  '为什么房主保险重要',
#  '人寿保险成长时会发生什么',
#  '如何找出有多少人寿保险',
#  '为什么选择长期护理保险',
#  '2014年我可以否认健康保险吗',
#  '美国银行出售人寿保险',
#  'PPO为健康保险提供什么',
#  '租金保险通常覆盖什么',
#  '家庭保险是否会覆盖气体泄漏',
#  'Obamacare会提高我的医疗保险费吗',
#  '我们有多少人寿保险代理人',
#  '需要多长时间才能获得家庭保险捆绑',
#  '谁有最便宜的人寿保险费率',
#  '什么是更好的期限或全人寿保险',
#  '医疗保险考试包括什么',
#  '医疗保险支付超声波',
#  '401K计算为退休计划吗',
#  '家庭保险是否覆盖单位',
#  '我可以在哪里兼职和获得健康保险',
#  '一辆跑车有多少保险',
#  '难以获得残疾保险',
#  '我可以从没有保险的私人派对开车吗',
#  '你能多快得到汽车保险',
#  '十七岁的摩托车保险有多少',
#  '如果每个人都死亡',
#  '租赁者保险多长时间',
#  '我的汽车保险可以叫我吗',
#  '健康保险是否涵盖宫内节育器',
#  '医疗保险覆盖家庭护理援助',
#  '我可以要求房主对我的税收保险吗',
#  '房主保险需要什么',
#  '在伊斯兰教中禁止人寿保险吗',
#  '什么是全人寿保险的目的',
#  '如何在阿拉巴马州获得人寿保险牌照',
#  '租客保险是否涵盖动物',
#  '没有赡养费的单身人士需要人寿保险吗',
#  '什么是最佳人寿保险公司',
#  '什么是房主保险粘合剂',
#  '对健康保险可以扣除的是什么意思',
#  '联邦政府是否提供残疾保险',
#  '医疗保险支付腹部成形术吗',
#  '汽车保险覆盖面对我来说是什么',
#  '什么是人寿保险',
#  '你可以在普遍的人寿保险中现金吗',
#  '全人寿保险的平均成本是多少',
#  '家庭保险报价需要什么信息',
#  '什么是集团普遍人寿保险',
#  '我应该有多少人寿保险',
#  '购买人寿时需要什么',
#  '国家农场租赁保险是否覆盖盗窃',
#  '租客保险是否盖车库物品',
#  '我需要地震保险吗',
#  '谁符合人寿保险资格',
#  '租客保险在火灾中遇到什么',
#  '什么是保障欠租人保险',
#  '汽车保险费用多少',
#  '人寿保险可以竞争吗',
#  '护理家庭护理是由医疗保险覆盖吗',
#  '什么是人寿保险报价',
#  '什么时候有人符合医疗保险D部分',
#  '我可以在另一个国家使用我的健康保险吗',
#  '为什么要翻转我的401K',
#  '您需要在缅因州出售人寿的许可证吗',
#  '医生有多少伤残保险',
#  '医疗保险可以三分之一吗',
#  '什么是HSA健康保险计划',
#  '健康保险的年龄限制是多少',
#  '如何找到注册投资顾问',
#  '谁能兑现人寿保险',
#  '一个人有两个人寿保险政策吗',
#  '2014年什么是医疗保险',
#  '何时开始长期护理保险',
#  '怀俄明州如何获得医疗保险资格',
#  '谁应该得到残疾保险',
#  '最便宜的租客保险在哪里',
#  '人寿保险可以信托吗',
#  '什么是没有健康保险在Obamacare下的罚款',
#  '如何获得房主保险报价',
#  '人寿保险是否缴纳税款',
#  '汽车保险在加利福尼亚有多少是全覆盖的',
#  '你可以在线申请Medicare',
#  '我应该有多少年金',
#  '汽车保险可以在您的信用报告吗',
#  '我正在越过国家',
#  'PCN站在健康保险卡上什么',
#  '多少长期护理保险足够',
#  '买房租的保险怎么办',
#  '健康保险通过工作多少钱',
#  '新泽西州个人健康保险多少',
#  '房主保险覆盖失去的结婚戒指',
#  '人寿保险需要血液检查吗',
#  '汽车保险是否覆盖司机或汽车',
#  '如何购买医疗保险',
#  '孩子可以多长时间养父母健康保险',
#  '安全视野医疗保险补充',
#  '租金保险费用一个月多少',
#  '哪个医疗保险B部分计划是最好的',
#  '有多少雇主提供残疾保险',
#  '什么类型的工作提供最佳健康保险',
#  '什么是良好的租赁保险政策',
#  '你应该有多长时间的人寿保险',
#  '医疗保险补贴F是什么',
#  '人寿保险是否进入房地产',
#  '什么是军人集团人寿保险',
#  '为什么要购买补充残疾保险',
#  '没有身体健康吗',
#  '我的租客保险是否覆盖我的手机',
#  '家庭危害保险是什么',
#  '你能否在医疗保险方面声称成形术',
#  '全人寿保险是否真的有意义',
#  '为什么人寿保险这么便宜',
#  '弗吉尼亚州需要租赁保险吗',
#  '医疗保险覆盖眼镜多少钱',
#  '你如何确定你需要多长时间的人寿保险',
#  '你可以取消人寿保险吗',
#  '如果我没有健康保险',
#  '什么是服务承包商的医疗费用',
#  '租客保险是否盖枪盗窃',
#  '什么是儿童最佳人寿保险',
#  'Allstate做人寿保险',
#  '宾夕法尼亚州的汽车保险最低费用是多少',
#  '我可以有私人保险和医疗保险吗',
#  '为什么要买残疾保险',
#  '谁能添加到我的汽车保险',
#  '你可以取消全人寿保险吗',
#  '汽车保险在加价车票之后增加多少',
#  '汽车保险何时下跌',
#  '残疾保险是否推荐',
#  '为什么全民保险这么昂贵',
#  '谁应该拥有你的人寿保险',
#  '什么是替代医疗保险',
#  '我父母的人寿保险是多少',
#  '谁出售定期人寿保险',
#  '谁能购买人寿保险',
#  '我的代理人告诉我我已经涵盖了产前保健',
#  '谁卖最便宜的汽车保险',
#  '我需要什么牌子卖残疾保险',
#  '如果失业',
#  '我可以把我的老人家长给我的健康保险吗',
#  '什么是全人寿保险',
#  '你可以在人寿保险中现金吗',
#  '什么是人寿保险证书',
#  '什么是租赁保险的使用',
#  '汽车保险是否覆盖鹿',
#  '医疗保险是否可以用尽',
#  '什么是两种类型的残疾保险',
#  '什么是不合格退休计划',
#  '什么是即时年金的排除比例',
#  '多少是健康保险的保险费',
#  '眼镜蛇健康保险好吗',
#  '需要信用检查才能获得人寿保险',
#  '为什么人们得到残疾保险',
#  '健康保险公司可以告诉你吸烟吗',
#  '如果你在医疗保险中',
#  '任何人都可以拿出人寿保险吗',
#  '什么时候需要商业汽车保险',
#  '为什么长期护理保险市场这么小',
#  '何时开始全员保险',
#  '如何将我的保险转让给另一辆车',
#  'ROP在人寿保险中意味着什么',
#  '什么是长期残疾保险',
#  '你有不止一个人寿保险吗',
#  '如何购买新房子的房主保险',
#  '如何获得我自己的健康保险',
#  '长期护理保险费可以扣除吗',
#  '债务人可以承担人寿保险吗',
#  '在哪里获得租赁保险',
#  '医疗保险批准金额多少是眼镜',
#  '人寿保险血液检查寻找什么',
#  '什么时候可以获得医疗福利',
#  '年金可以用于抵押品吗',
#  '什么是医疗保健中的MOOP',
#  '如何购买短期残疾保险',
#  '屋主保险盖屋顶塌方',
#  '为什么Roth',
#  '谁需要严重疾病保险',
#  '人寿保险公司如何知道你死了',
#  '哪里获得最佳健康保险',
#  '人寿保险如何便宜',
#  '汽车保险可以扣除多少',
#  '家庭保险在火灾中遇到什么',
#  '失业是否影响家庭保险',
#  '为什么要获得Medigap',
#  '住房保险费用是什么',
#  '花费多少钱来偿付全人寿保险',
#  '什么是顶帽退休计划',
#  '78岁可以获得人寿保险吗',
#  '家庭保险公司可以放弃你吗',
#  '健康保险是否覆盖牙种植体',
#  '如果我不能获得房主保险',
#  '宝力人寿保险是什么',
#  '人寿保险检查要多久清除',
#  '新墨西哥应该在哪里购买健康保险',
#  '什么是租赁保险',
#  'Suze',
#  '得克萨斯州一个人的健康保险多少',
#  '我可以用我的汽车保险租车吗',
#  '如何申请医疗保险B部分',
#  '我可以为我的孩子买车吗',
#  '医疗保险何时覆盖家庭保健',
#  '房主保险是否覆盖暖通空调',
#  '什么是401C的早期罚款',
#  '健康保险是否适用',
#  '平均租金保险费用多少',
#  '债务追回者可以追求人寿保险吗',
#  '个人健康保险费用多少',
#  '健康保险是否补贴',
#  '全人寿保险贷款如何运作',
#  '什么是汽车身体伤害保险',
#  '我需要多少保险',
#  '如何在线购买残疾保险',
#  '整形术是健康保险涵盖的吗',
#  '房东要求租客保险是否合法',
#  '医疗保险盖STD测试',
#  '我怎么知道我的车祸是否完成',
#  '房屋医疗保险涵盖什么',
#  '健康保险是否影响老年工人的就业',
#  '人寿保险通过遗嘱',
#  '谁能为不可撤销的人寿保险信托做出贡献',
#  '家庭日托需要什么样的保险',
#  '药物过量被人寿保险覆盖吗',
#  '谁是符合残疾保险条件',
#  '谁需要全人寿保险',
#  'D部分医疗保险是否免费',
#  '你有两个医疗保险和VA的好处',
#  '搬家时需要改车保险吗',
#  '如何选择合适的退休计划',
#  '家庭保险是否包含被盗现金',
#  '人寿保险的面值是多少',
#  '谁有最佳的Medigap计划',
#  '未成年人能否成为人寿保险受益人',
#  '密歇根州需要汽车保险吗',
#  '如何注册眼镜蛇健康保险',
#  '401',
#  '军人退休金是否合格退休计划',
#  '卖年金怎么办',
#  '每个人65岁以上是否符合医疗保险',
#  '如果您超过80岁',
#  '纽约人寿保险代理人有多少',
#  '独资经营者可以扣除残疾保险费吗',
#  '雇主可以向老年雇主收取更高的费用吗',
#  '房主的保险是否覆盖了地下室',
#  '如何通知医疗保险',
#  '医疗保险优势与医疗保险保险的区别是什么',
#  '健康保险为新生儿费用多少',
#  '汽车保险结算是否应纳税',
#  '租金保险是否包括被盗现金',
#  '为什么我们需要健康保险公司',
#  '我应该在俄亥俄州多少辆汽车保险',
#  '短期残疾保险多久',
#  '我退休时会有医疗保险吗',
#  '我的兄弟可以驾驶我的汽车没有保险吗',
#  '65岁之前可以享受医疗保险吗',
#  '为什么健康保险存在',
#  '医疗保险A和医疗保险B之间有什么区别',
#  '什么时候最好的时候买年金',
#  '人寿保险血液和尿液测试是什么',
#  '离婚期间人寿保险怎么办',
#  '哪里购买好人寿保险',
#  '基本租金保险费用多少',
#  '西北共同人寿保险投资良好',
#  '可以从终身人寿保险中获得现金吗',
#  '哪里可以获得低廉的租金保险',
#  '60岁的健康保险多少钱',
#  '您的投资组合应该在年金中多少',
#  '哪里可以得到没有车的保险',
#  '是否需要租赁保险',
#  '如何在房主保险上节省资金',
#  '什么是生命和TPD保险',
#  '你可以在其他人身上购买人寿吗',
#  '要成为保险代理人的学院专业学习是什么',
#  '医疗保险覆盖DME用品',
#  '你能否在宾夕法尼亚州借贷退休计划',
#  '长期护理保险费用是多少',
#  '康涅狄格州需要多少房主保险',
#  '医疗保险是否有房屋恢复',
#  '什么公司有最便宜的租客保险在宾夕法尼亚州',
#  '为什么有人被剥夺人寿保险',
#  'FAFSA计算年金吗',
#  '如何购买我自己的健康保险',
#  '我可以扣除汽车保险费吗',
#  '401K中的关键员工是谁',
#  '你可以从罗斯401K撤出吗',
#  '为什么进口汽车保险更昂贵',
#  '如果你生病',
#  '如果我吸烟',
#  '谁的人寿保险是不可靠的',
#  '现在是一个好时机去买年金吗',
#  '家庭住宅的住房金额是多少',
#  '我应该得到什么租赁保险',
#  '人寿是抵押的法定要求吗',
#  '字母T在医疗保险号码中是什么意思',
#  '人寿保险销售是个好职业吗',
#  '你住哪里影响你的汽车保险费率',
#  '丈夫和妻子都有Roth',
#  '健康保险在加拿大免费吗',
#  '我的配偶是否必须在我的汽车保险上',
#  '谁应该设立一个Roth',
#  'Geico是否提供定期人寿保险',
#  '什么是人寿保险创造一个即时财产',
#  '什么是自雇健康保险',
#  '没有健康保险多少罚款',
#  '什么是家庭保险',
#  '人寿保险费用是多少',
#  '我可以随时注册医疗保险D部分吗',
#  '谁应该是我人寿保险的受益人',
#  '什么是医疗保险区域C',
#  '租客保险是否包括盗窃自行车',
#  '什么是选择定期人寿保险',
#  '人人有健康保险吗',
#  '我可以在我的男朋友健康保险吗',
#  '全面覆盖健康保险',
#  '如何获得Obamacare',
#  '您需要在伊利诺斯出售人寿的许可证吗',
#  '为什么长期残疾保险重要',
#  '地下池增加房主保险吗',
#  '我们如何找出什么保险公司保险我的邻居的房子',
#  '你可以1035从人寿到年金',
#  '我应该在密歇根州购买长期护理保险',
#  '2014年医疗保险费将上涨吗',
#  '我可以在另一个州有汽车保险吗',
#  '人寿应该多少钱',
#  '医疗保险D部封盖Cymbalta',
#  '如何获得短期残疾保险',
#  '人寿保险代理人在伊利诺伊州做了多少工作',
#  '医疗保险覆盖丙型肝炎筛查',
#  '谁调整可变年金',
#  '谁提供购买寿命年金',
#  '为什么我需要严重的疾病保险',
#  'AARP有汽车保险吗',
#  '汽车保险报价是否会影响您的信用评分',
#  '医疗保险覆盖在老人家庭护理中吗',
#  '人寿保险的两大基本类型是什么',
#  '哪一类人寿保险派息',
#  '农场局提供租赁保险吗',
#  '为什么我的汽车保险上涨',
#  '雇主可以取消健康保险吗',
#  '你不会因没有健康保险而被罚款多少',
#  '哪个是最好的经典汽车保险',
#  'Medigap的好处是什么',
#  '网上汽车保险报价准确度如何',
#  '丈夫有多少人寿保险',
#  '残疾保险是否涵盖酒精中毒',
#  '谁能在田纳西州卖年金',
#  '什么资格作为健康保险的资格赛',
#  'Esurance是否提供人寿保险',
#  '健康保险对家庭3成本有多大',
#  '何时购买长期残疾保险',
#  '哪些私人健康保险涵盖整容手术',
#  '房主保险盖屋顶损坏',
#  '哪里买个人残疾保险',
#  '如果我参加工作中的退休计划',
#  '国税局能否挽救人寿保险',
#  '你可以从人寿保险贷款吗',
#  '为什么我的房东想要我租赁保险',
#  '医疗保险支付任何牙科工作',
#  '什么是保险替代成本在房主保险',
#  '汽车保险怎么开始',
#  '如何选择最佳汽车保险',
#  '谁出售长期护理保险',
#  '医疗保险是否覆盖艾滋病毒药物',
#  '什么被认为健康保险失效',
#  '我需要什么信息获得汽车保险',
#  '什么是最佳Medigap或Medicare优势',
#  '购买我自己的健康保险是否便宜',
#  '医疗保险覆盖的折射',
#  '全球人寿保险有多好',
#  '我可以用现有条件购买健康保险吗',
#  '租金在马萨诸塞州的保险费用多少',
#  '健康保险是否覆盖流感疫苗',
#  '我能救我的人寿保险公司吗',
#  '房主保险在浴室里是否覆盖水损害',
#  '固定年金有多好',
#  '人寿保险是否可以由债权人承担',
#  '如何注册Medicare',
#  '罗德岛的医疗保险资格是多少',
#  '退休计划多少钱',
#  '什么是年金错误',
#  '租赁保险在爱荷华州覆盖什么',
#  '我可以驾驶我父母的汽车保险吗',
#  '你如何购买年金',
#  '我可以获得长期护理保险的资格吗',
#  '房主保险是否覆盖爆管',
#  '401K如果退出工作怎么办',
#  '如果我有狼疮',
#  '年金可以丢钱吗',
#  '人寿如何保险资产',
#  '房主保险是否会从屋顶泄漏中覆盖水面',
#  '什么时候可以从医疗保险优势切换到Medigap',
#  '什么是实行人寿保险的罚则',
#  '高免赔额健康保险费用多少',
#  '我可以扣除长期护理保险费吗',
#  '我应该做长期残疾保险吗',
#  '什么影响到房主的保险费率',
#  '家庭保险是否覆盖了泄漏屋顶',
#  '我需要多少年的长期护理保险',
#  '房主保险托管如何工作',
#  '人寿保险是如何在死亡时征收的',
#  '私人残疾保险如何影响社会保障残疾',
#  '谁提供残疾保险',
#  '医疗保险B部分盖实验室工作吗',
#  '什么是最佳长期护理保险公司',
#  '利润分享退休计划',
#  '医疗费用一年多少钱',
#  '租客保险是否覆盖手机损坏',
#  '华盛顿医疗保险的资格是多少',
#  '19岁以上汽车保险费用多少',
#  '长期护理保险可以固定吗',
#  '什么是健康保险的免赔额',
#  '什么是汽车保险堆',
#  '租客保险是否覆盖子列表',
#  '旅行保险是否值钱',
#  '受家庭保险覆盖的湿腐蚀',
#  '汽车保险在MA中多少钱',
#  '汽车保险可以在您父母的姓名吗',
#  '租金保险是否涵盖洪灾',
#  '长期护理保险费可以增加吗',
#  '房屋保险何时开始',
#  '何时可以购买Medigap政策',
#  '健康保险什么时候覆盖一个馅饼馅饼',
#  'Aflac癌症保险支付什么',
#  '如何检查供应商的医疗保险资格',
#  'UMPD是否对被盗车辆造成损害',
#  'Genworth长期护理保险涵盖什么',
#  '残疾保险的定义是什么',
#  '房主保险是否覆盖电涌',
#  '严重疾病保险是否覆盖关节炎',
#  '企业家如何获得健康保险',
#  '哪种残疾保险是最好的',
#  '医疗保健有效地用于帮助美国人吗',
#  '什么是儿童骑手人寿保险',
#  '什么是第一人寿保险公司',
#  '退休计划做什么',
#  'Grange汽车保险是否租用汽车',
#  '你可以在线购买人寿保险吗',
#  '家庭保险怎么办',
#  '医疗保险支付输血费用吗',
#  '谁免于购买健康保险',
#  '医疗保险是多少B部分',
#  '关键疾病保险的好处是什么',
#  '我可以开一家汽车保险公司吗',
#  '人寿保险是否必要',
#  '为什么人寿是单方面合同',
#  '什么是医疗保险终身储备天',
#  '租客保险是否涵盖车辆损坏',
#  '什么是最佳的Medigap保险',
#  '什么是健康保险的裁决',
#  '人寿保险被认为是医疗补助的资产',
#  '你需要多少残疾保险',
#  '一辆新车全面覆盖汽车保险多少',
#  '特拉华州最好的人寿保险是什么',
#  '汽车保险公司可以放弃你吗',
#  '什么是Medigap',
#  '自由相关租车保险',
#  '要花多长时间才能收到人寿保险',
#  'VA提供残疾保险吗',
#  '基本租金保险多少',
#  'Aetna学生健康保险是什么',
#  '寿险如何快速发放',
#  '谁必须购买健康保险',
#  '残疾保险是一个好主意吗',
#  '家庭保险会增加一个池吗',
#  '什么是不可撤销的人寿保险信托的主要目的',
#  '没有健康保险的尿分析费用多少',
#  '我可以在不属于我的汽车上获得保险吗',
#  '富国银行是否提供人寿保险',
#  '退休储蓄计划可以有多少选择',
#  '为什么我需要Medigap',
#  '人寿保险是否真的有效',
#  '整个生命在保险中意味着什么',
#  '年金公司如何赚钱',
#  '什么是最便宜的汽车保险',
#  '汽车保险联邦法律',
#  '人寿保险需要多长时间',
#  '房主保险是否覆盖了使用',
#  '医疗保健HIC代表什么',
#  '为什么全人寿保险好投资',
#  '房主保险覆盖电力浪潮',
#  '什么是集体健康保险',
#  '年金利率上涨吗',
#  '什么时候可以注册健康保险',
#  '租人保险是否需要',
#  '什么是递延年金',
#  '如何计算合格的年金',
#  '人寿可以得到什么',
#  '我可以保险',
#  '如果我的车被盗',
#  '为什么我们需要严重的疾病保险',
#  '何时开启强制性汽车保险',
#  '国营农场有定期人寿保险吗',
#  '典型的房主保险多少',
#  '美国健康保险在海外工作吗',
#  '什么是最好的房主保险',
#  '什么是少年全人寿保险',
#  '在房主保险中要寻找什么',
#  '不能拥有汽车可以获得Sr22保险吗',
#  '人寿保险社区财产',
#  '谁拥有西南生活',
#  '汽车保险金多少钱',
#  '我需要知道什么才能获得房主保险',
#  '汽车保险是否覆盖了一个破裂的挡风玻璃',
#  '谁在北达科他州管理人寿保险',
#  '你能否继续保持父母的健康保险',
#  '公司是否要提供退休计划',
#  '租客保险是否对房产造成损害',
#  '退休时我需要人寿保险吗',
#  '群变人寿保险如何运作',
#  '为什么选择Medigap或Medicare的优势',
#  '两个人的健康保险多少钱',
#  '如何在线销售人寿保险',
#  '我可以在线报价人寿保险吗',
#  '一个人死后长时间得到人寿保险',
#  '你可以从整个人寿保险中借钱吗',
#  '人寿保险与健康保险的区别是什么',
#  '如何注册医疗保险B部分在线',
#  'AD',
#  '健康保险是否覆盖ED药物',
#  '谁获得医疗保险总结通知',
#  '什么时候是Medicare主要付款人',
#  '医疗支付医生多少钱',
#  '什么时候什么时候适合医疗保险',
#  '普遍人寿保险是否过期',
#  ...]

# %%
import jieba
def cut(string): return list(jieba.cut(string))

# %%
TOKEN = []

# %%
for i, line in enumerate(clean_str_list):
    if i%1000 == 0: print(i)
    TOKEN += cut(line)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000

# %%
len(TOKEN)
# Out:
# 73705

# %%
from collections import Counter
words_count = Counter(TOKEN)
words_count.most_common(10)
# Out:
# [('保险', 4904),
#  ('的', 3089),
#  ('人寿保险', 2865),
#  ('什么', 2621),
#  ('是', 2314),
#  ('吗', 2296),
#  ('我', 1881),
#  ('是否', 1802),
#  ('可以', 1615),
#  ('健康', 1487)]

# %%
def prob_1(word): return words_count[word] / len(TOKEN)

# %%
prob_1('保险')
# Out:
# 0.06653551319449155

# %%
TOKEN_2_GRAM = [''.join(TOKEN[i:i+2]) for i in range(len(TOKEN[:-1]))] 
len(TOKEN_2_GRAM)
# Out:
# 73704

# %%
words_count_2 = Counter(TOKEN_2_GRAM)
words_count_2.most_common(10)
# Out:
# [('健康保险', 1323),
#  ('什么是', 1148),
#  ('保险是否', 957),
#  ('我的', 687),
#  ('残疾保险', 646),
#  ('房主保险', 599),
#  ('是否覆盖', 496),
#  ('保险吗', 473),
#  ('我可以', 463),
#  ('年金', 455)]

# %%
def prob_2(word1, word2):
    if word1 + word2 in words_count_2: return words_count_2[word1+word2] / len(TOKEN_2_GRAM)
    return 1 / len(TOKEN_2_GRAM)

# %%
prob_2('健康', '保险')
# Out:
# 0.017950179094757407

# %%
def get_probability(sentence):
    words = cut(sentence)
    sentence_pro = 1
    for i,word in enumerate(words[:-1]):
        next_ = words[i+1]
        sentence_pro *= prob_2(word, next_)
    return sentence_pro

# %%
get_probability('小明今天抽奖抽到一架波音飞机')
# Out:
# 6.238118940475765e-30

# %% [markdown]
# #### 3. 获得最优质的的语言

# %% [markdown]
# 当我们能够生成随机的语言并且能判断之后，我们就可以生成更加合理的语言了。请定义 generate_best 函数，该函数输入一个语法 + 语言模型，能够生成**n**个句子，并能选择一个最合理的句子:

# %% [markdown]
# 提示，要实现这个函数，你需要Python的sorted函数

# %%
sorted([1, 3, 5, 2])
# Out:
# [1, 2, 3, 5]

# %% [markdown]
# 这个函数接受一个参数key，这个参数接受一个函数作为输入，例如

# %%
sorted([(2, 5), (1, 4), (5, 0), (4, 4)], key=lambda x: x[0])
# Out:
# [(1, 4), (2, 5), (4, 4), (5, 0)]

# %% [markdown]
# 能够让list按照第0个元素进行排序.

# %%
sorted([(2, 5), (1, 4), (5, 0), (4, 4)], key=lambda x: x[1])
# Out:
# [(5, 0), (1, 4), (4, 4), (2, 5)]

# %% [markdown]
# 能够让list按照第1个元素进行排序.

# %%
sorted([(2, 5), (1, 4), (5, 0), (4, 4)], key=lambda x: x[1], reverse=True)
# Out:
# [(2, 5), (1, 4), (4, 4), (5, 0)]

# %% [markdown]
# 能够让list按照第1个元素进行排序, 但是是递减的顺序。

# %% [markdown]
# >

# %%
def generate_best(gram, target): # you code here
    str_with_prob = [(g, get_probability(g)) for g in generate_n(gram, target)]
    return sorted(str_with_prob, key = lambda x:x[1], reverse=True)[0]

# %%
generate_best(gram, 'host')
# Out:
# ('您好我是82号,您需要玩一玩喝酒吗？', 3.154939572274237e-52)

# %% [markdown]
# 好了，现在我们实现了自己的第一个AI模型，这个模型能够生成比较接近于人类的语言。

# %% [markdown]
# >

# %% [markdown]
# Q: 这个模型有什么问题？ 你准备如何提升？

# %% [markdown]
# Ans:

# %% [markdown]
# >

# %% [markdown]
# ##### 以下内容为可选部分，对于绝大多数同学，能完成以上的项目已经很优秀了，下边的内容如果你还有精力可以试试，但不是必须的。

# %% [markdown]
# #### 4. (Optional) 完成基于Pattern Match的语句问答
# > 我们的GitHub仓库中，有一个assignment-01-optional-pattern-match，这个难度较大，感兴趣的同学可以挑战一下。

# %% [markdown]
# #### 5. (Optional) 完成阿兰图灵机器智能原始论文的阅读
# 1. 请阅读阿兰图灵关于机器智能的原始论文：https://github.com/Computing-Intelligence/References/blob/master/AI%20%26%20Machine%20Learning/Computer%20Machinery%20and%20Intelligence.pdf
# 2. 并按照GitHub仓库中的论文阅读模板，填写完毕后发送给我: mqgao@kaikeba.com 谢谢

# %% [markdown]
# >

# %% [markdown]
# 各位同学，我们已经完成了自己的第一个AI模型，大家对人工智能可能已经有了一些感觉，人工智能的核心就是，我们如何设计一个模型、程序，在外部的输入变化的时候，我们的程序不变，依然能够解决问题。人工智能是一个很大的领域，目前大家所熟知的深度学习只是其中一小部分，之后也肯定会有更多的方法提出来，但是大家知道人工智能的目标，就知道了之后进步的方向。

# %% [markdown]
# 然后，希望大家对AI不要有恐惧感，这个并不难，大家加油！

# %% [markdown]
# >

# %% [markdown]
# ![](https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1561828422005&di=48d19c16afb6acc9180183a6116088ac&imgtype=0&src=http%3A%2F%2Fb-ssl.duitang.com%2Fuploads%2Fitem%2F201807%2F28%2F20180728150843_BECNF.thumb.224_0.jpeg)
